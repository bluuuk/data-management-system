# %% [raw]
# https://naiveskill.com/mongodb-with-python/
#
# db=database name
# coll=collection name
#
# whichCollection.find()
# db.coll.insert_one(recordJSON)
# db.coll.insert_many(recordJSON)
# db.coll.delete_one(...)
# db.coll.delete_many(...)
# db.coll.find({ attr: { $operator: value} })
# db.coll.find({ attr: { $operator: value} [, { attr: { $operator: value}] })
# db.coll.update({attr:value},{$set:{attr:value}})
# db.coll.updateMany( { attr: {$op: val} } , { $inc: { attr: val} }
# db.coll.updateMany( { attr: {$op: val} } , { $inc: { attr: val} }
# aggreg=db.coll.aggregate( [
# { '$group': { '_id': attr, 'total': { ’$op': ”$attr" } } }, { '$sort': { 'total': -1 } } ])
#
#
# cur=db.coll.aggregate([
#     { "$lookup":
#         {
#        from: <collection to join>,
#        localField: <field from the input documents>,
#        foreignField: <field from the documents of the "from" collection>,
#        as: <output array field>
#         }
#     }
# ])
#
#
# SOME OPERATORS:
# Name Description
# $eq Matches values that are equal to a specified value.
# $gt Matches values that are greater than a specified value. $gte Matches values that are greater than or equal to a specified value.
# $in Matches any of the values specified in an array.
# $lt Matches values that are less than a specified value. $lte Matches values that are less than or equal to a specified value.
# $ne Matches all values that are not equal to a specified value.
# $nin Matches none of the values specified in an array.
#
# Logical
# Name Description
# $and Joins query clauses with a logical AND returns all documents that match the conditions of both clauses.
# $not Inverts the effect of a query expression and returns documents that do not match the query expression.
# $nor Joins query clauses with a logical NOR returns all documents that fail to match both clauses.
# $or Joins query clauses with a logical OR returns all documents that match the conditions of either clause.

# %%
import pymongo

# %% [markdown]
# # launch the daemon

# %% [markdown]
# inside the bin dir of mongo
# mkdir aulaMONGODB
# Macs-MBP-4:bin pedro$ mongod --dbpath aulaMONGODB

# %% [markdown]
# # Connect the client

# %%
client = pymongo.MongoClient("mongodb://host.docker.internal:32768/")

# %%
client.list_database_names()
# Out:
# ['admin', 'config', 'local', 'med_data']

# %% [markdown]
# # import restaurants and neighbourhoods JSON

# %%
# !wget https://raw.githubusercontent.com/mongodb/docs-assets/primer-dataset/primer-dataset.json
# Out:
# --2023-03-21 20:01:28--  https://raw.githubusercontent.com/mongodb/docs-assets/primer-dataset/primer-dataset.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11874761 (11M) [text/plain]
# Saving to: ‘primer-dataset.json’
#
# primer-dataset.json 100%[===================>]  11.32M  8.57MB/s    in 1.3s
#
# 2023-03-21 20:01:31 (8.57 MB/s) - ‘primer-dataset.json’ saved [11874761/11874761]

# %% [markdown]
# ## See databases

# %%
client.list_database_names()

# %% [markdown]
# ## Connect to restaurants, reference restaurants

# %%
db = client['restaurants']

# %%
client['restaurants'].list_collection_names()
# Out:
# []

# %%
restaurants=client['restaurants']['restaurants']

# %%
import json
with open('./work/restaurants.json') as f:
  data = f.readlines()
  file_data = json.loads("[" + ",".join(data) + "]")
 
restaurants.insert_many(file_data)

# %%
import pprint
for restaurant in restaurants.find()[:5]:
    pprint.pprint(restaurant)
# Out:
# {'_id': ObjectId('641a0e7d5e7639d44270ac41'),
#  'address': {'building': '1007',
#              'coord': [-73.856077, 40.848447],
#              'street': 'Morris Park Ave',
#              'zipcode': '10462'},
#  'borough': 'Bronx',
#  'cuisine': 'Bakery',
#  'grades': [{'date': {'$date': 1393804800000}, 'grade': 'A', 'score': 2},
#             {'date': {'$date': 1378857600000}, 'grade': 'A', 'score': 6},
#             {'date': {'$date': 1358985600000}, 'grade': 'A', 'score': 10},
#             {'date': {'$date': 1322006400000}, 'grade': 'A', 'score': 9},
#             {'date': {'$date': 1299715200000}, 'grade': 'B', 'score': 14}],
#  'name': 'Morris Park Bake Shop',
#  'restaurant_id': '30075445'}
# {'_id': ObjectId('641a0e7d5e7639d44270ac42'),
#  'address': {'building': '469',
#              'coord': [-73.961704, 40.662942],
#              'street': 'Flatbush Avenue',
#              'zipcode': '11225'},
#  'borough': 'Brooklyn',
#  'cuisine': 'Hamburgers',
#  'grades': [{'date': {'$date': 1419897600000}, 'grade': 'A', 'score': 8},
#             {'date': {'$date': 1404172800000}, 'grade': 'B', 'score': 23},
#             {'date': {'$date': 1367280000000}, 'grade': 'A', 'score': 12},
#             {'date': {'$date': 1336435200000}, 'grade': 'A', 'score': 12}],
#  'name': "Wendy'S",
#  'restaurant_id': '30112340'}
# {'_id': ObjectId('641a0e7d5e7639d44270ac43'),
#  'address': {'building': '351',
#              'coord': [-73.98513559999999, 40.7676919],
#              'street': 'West   57 Street',
#              'zipcode': '10019'},
#  'borough': 'Manhattan',
#  'cuisine': 'Irish',
#  'grades': [{'date': {'$date': 1409961600000}, 'grade': 'A', 'score': 2},
#             {'date': {'$date': 1374451200000}, 'grade': 'A', 'score': 11},
#             {'date': {'$date': 1343692800000}, 'grade': 'A', 'score': 12},
#             {'date': {'$date': 1325116800000}, 'grade': 'A', 'score': 12}],
#  'name': 'Dj Reynolds Pub And Restaurant',
#  'restaurant_id': '30191841'}
# {'_id': ObjectId('641a0e7d5e7639d44270ac44'),
#  'address': {'building': '2780',
#              'coord': [-73.98241999999999, 40.579505],
#              'street': 'Stillwell Avenue',
#              'zipcode': '11224'},
#  'borough': 'Brooklyn',
#  'cuisine': 'American',
#  'grades': [{'date': {'$date': 1402358400000}, 'grade': 'A', 'score': 5},
#             {'date': {'$date': 1370390400000}, 'grade': 'A', 'score': 7},
#             {'date': {'$date': 1334275200000}, 'grade': 'A', 'score': 12},
#             {'date': {'$date': 1318377600000}, 'grade': 'A', 'score': 12}],
#  'name': 'Riviera Caterer',
#  'restaurant_id': '40356018'}
# {'_id': ObjectId('641a0e7d5e7639d44270ac45'),
#  'address': {'building': '97-22',
#              'coord': [-73.8601152, 40.7311739],
#              'street': '63 Road',
#              'zipcode': '11374'},
#  'borough': 'Queens',
#  'cuisine': 'Jewish/Kosher',
#  'grades': [{'date': {'$date': 1416787200000}, 'grade': 'Z', 'score': 20},
#             {'date': {'$date': 1358380800000}, 'grade': 'A', 'score': 13},
#             {'date': {'$date': 1343865600000}, 'grade': 'A', 'score': 13},
#             {'date': {'$date': 1323907200000}, 'grade': 'B', 'score': 25}],
#  'name': 'Tov Kosher Kitchen',
#  'restaurant_id': '40356068'}

# %% [markdown]
# ## Compute the average scores of the restaurants.

# %% [markdown]
# We pass an array to the aggregate function.
#
# The $unwind parameter is used to deconstruct the grades array in order to output a document for each element.
#
# Next we use the $match parameter including everything (by using open and closing braces). We could filter further here by providing additional criteria.
#
# Next we use the $group parameter to group the data that we want to apply the computation to.
#
# Finally we create new key called “Avg grade” and apply the $avg (average) parameter to the grades scores of individual restaurants referencing grades followed by a dot and the score key.
#
# There are many other parameters that can be used for common computations such as $sum, $min, $max etc.

# %%
#complete the next code to do it...see the result...WHY DOES IT NOT WORK? go back to understand based 
#on restaurants data

result = restaurants.aggregate(
  [
     {"$match": {}}, 
     {"$group": {"_id": "$restaurant_id", "Avg grade": {"$avg": "$grades.score" }
      }
      }
  ]
)

# %%
for item in result:
    print(item)
# Out:
# {'_id': '50012159', 'Avg grade': None}
# {'_id': '50012259', 'Avg grade': None}
# {'_id': '40752011', 'Avg grade': None}
# {'_id': '41644186', 'Avg grade': None}
# {'_id': '50002360', 'Avg grade': None}
# {'_id': '41191695', 'Avg grade': None}
# {'_id': '41344604', 'Avg grade': None}
# {'_id': '50006314', 'Avg grade': None}
# {'_id': '41642708', 'Avg grade': None}
# {'_id': '40364389', 'Avg grade': None}
# {'_id': '41228799', 'Avg grade': None}
# {'_id': '40884510', 'Avg grade': None}
# {'_id': '41023695', 'Avg grade': None}
# {'_id': '41589950', 'Avg grade': None}
# {'_id': '41665912', 'Avg grade': None}
# {'_id': '41721692', 'Avg grade': None}
# {'_id': '50008870', 'Avg grade': None}
# {'_id': '50010096', 'Avg grade': None}
# {'_id': '40620183', 'Avg grade': None}
# {'_id': '41263893', 'Avg grade': None}
# {'_id': '40368021', 'Avg grade': None}
# {'_id': '41171966', 'Avg grade': None}
# {'_id': '41070857', 'Avg grade': None}
# {'_id': '50002573', 'Avg grade': None}
# {'_id': '50001639', 'Avg grade': None}
# {'_id': '40900938', 'Avg grade': None}
# {'_id': '40591271', 'Avg grade': None}
# {'_id': '41707843', 'Avg grade': None}
# {'_id': '41475604', 'Avg grade': None}
# {'_id': '40395525', 'Avg grade': None}
# {'_id': '41695456', 'Avg grade': None}
# {'_id': '41289885', 'Avg grade': None}
# {'_id': '41627909', 'Avg grade': None}
# {'_id': '41710730', 'Avg grade': None}
# {'_id': '50001473', 'Avg grade': None}
# {'_id': '40725853', 'Avg grade': None}
# {'_id': '50006091', 'Avg grade': None}
# {'_id': '50010066', 'Avg grade': None}
# {'_id': '50010791', 'Avg grade': None}
# {'_id': '41122196', 'Avg grade': None}
# {'_id': '41437564', 'Avg grade': None}
# {'_id': '41622143', 'Avg grade': None}
# {'_id': '40674838', 'Avg grade': None}
# {'_id': '41689524', 'Avg grade': None}
# {'_id': '41183605', 'Avg grade': None}
# {'_id': '41423142', 'Avg grade': None}
# {'_id': '41710136', 'Avg grade': None}
# {'_id': '50005183', 'Avg grade': None}
# {'_id': '50015794', 'Avg grade': None}
# {'_id': '41704639', 'Avg grade': None}
# {'_id': '50017418', 'Avg grade': None}
# {'_id': '41597988', 'Avg grade': None}
# {'_id': '50016565', 'Avg grade': None}
# {'_id': '40390781', 'Avg grade': None}
# {'_id': '50002012', 'Avg grade': None}
# {'_id': '41466809', 'Avg grade': None}
# {'_id': '41640196', 'Avg grade': None}
# {'_id': '50015982', 'Avg grade': None}
# {'_id': '50007604', 'Avg grade': None}
# {'_id': '40745618', 'Avg grade': None}
# {'_id': '40396037', 'Avg grade': None}
# {'_id': '50001245', 'Avg grade': None}
# {'_id': '40991835', 'Avg grade': None}
# {'_id': '41194925', 'Avg grade': None}
# {'_id': '41478516', 'Avg grade': None}
# {'_id': '41148931', 'Avg grade': None}
# {'_id': '40918464', 'Avg grade': None}
# {'_id': '41711612', 'Avg grade': None}
# {'_id': '50000254', 'Avg grade': None}
# {'_id': '50013473', 'Avg grade': None}
# {'_id': '40737933', 'Avg grade': None}
# {'_id': '40788706', 'Avg grade': None}
# {'_id': '41155448', 'Avg grade': None}
# {'_id': '41364577', 'Avg grade': None}
# {'_id': '41618169', 'Avg grade': None}
# {'_id': '41325258', 'Avg grade': None}
# {'_id': '50007739', 'Avg grade': None}
# {'_id': '41386642', 'Avg grade': None}
# {'_id': '40748086', 'Avg grade': None}
# {'_id': '41158964', 'Avg grade': None}
# {'_id': '41507194', 'Avg grade': None}
# {'_id': '41261371', 'Avg grade': None}
# {'_id': '41116435', 'Avg grade': None}
# {'_id': '41225996', 'Avg grade': None}
# {'_id': '41713374', 'Avg grade': None}
# {'_id': '41526628', 'Avg grade': None}
# {'_id': '50000057', 'Avg grade': None}
# {'_id': '41680534', 'Avg grade': None}
# {'_id': '50001364', 'Avg grade': None}
# {'_id': '50001762', 'Avg grade': None}
# {'_id': '50002268', 'Avg grade': None}
# {'_id': '50003789', 'Avg grade': None}
# {'_id': '40570508', 'Avg grade': None}
# {'_id': '41311425', 'Avg grade': None}
# {'_id': '41339607', 'Avg grade': None}
# {'_id': '40397723', 'Avg grade': None}
# {'_id': '50016634', 'Avg grade': None}
# {'_id': '41440468', 'Avg grade': None}
# {'_id': '50017456', 'Avg grade': None}
# {'_id': '41004284', 'Avg grade': None}
# {'_id': '50018945', 'Avg grade': None}
# {'_id': '40402377', 'Avg grade': None}
# {'_id': '40797688', 'Avg grade': None}
# {'_id': '50000192', 'Avg grade': None}
# {'_id': '40790556', 'Avg grade': None}
# {'_id': '50007437', 'Avg grade': None}
# {'_id': '41540004', 'Avg grade': None}
# {'_id': '41608817', 'Avg grade': None}
# {'_id': '50001840', 'Avg grade': None}
# {'_id': '40564078', 'Avg grade': None}
# {'_id': '41671082', 'Avg grade': None}
# {'_id': '50009874', 'Avg grade': None}
# {'_id': '41459183', 'Avg grade': None}
# {'_id': '41253818', 'Avg grade': None}
# {'_id': '41242943', 'Avg grade': None}
# {'_id': '50001168', 'Avg grade': None}
# {'_id': '41603460', 'Avg grade': None}
# {'_id': '41193681', 'Avg grade': None}
# {'_id': '50012659', 'Avg grade': None}
# {'_id': '50018237', 'Avg grade': None}
# {'_id': '40577915', 'Avg grade': None}
# {'_id': '41544565', 'Avg grade': None}
# {'_id': '41688142', 'Avg grade': None}
# {'_id': '41656659', 'Avg grade': None}
# {'_id': '50006295', 'Avg grade': None}
# {'_id': '41312239', 'Avg grade': None}
# {'_id': '41510896', 'Avg grade': None}
# {'_id': '41390371', 'Avg grade': None}
# {'_id': '41504220', 'Avg grade': None}
# {'_id': '41459124', 'Avg grade': None}
# {'_id': '40570920', 'Avg grade': None}
# {'_id': '41017547', 'Avg grade': None}
# {'_id': '50015827', 'Avg grade': None}
# {'_id': '41313271', 'Avg grade': None}
# {'_id': '40948589', 'Avg grade': None}
# {'_id': '50015308', 'Avg grade': None}
# {'_id': '50008416', 'Avg grade': None}
# {'_id': '50010628', 'Avg grade': None}
# {'_id': '40973369', 'Avg grade': None}
# {'_id': '50014720', 'Avg grade': None}
# {'_id': '40985814', 'Avg grade': None}
# {'_id': '40912833', 'Avg grade': None}
# {'_id': '40986218', 'Avg grade': None}
# {'_id': '41338296', 'Avg grade': None}
# {'_id': '50007296', 'Avg grade': None}
# {'_id': '41689229', 'Avg grade': None}
# {'_id': '41458617', 'Avg grade': None}
# {'_id': '50008539', 'Avg grade': None}
# {'_id': '41636999', 'Avg grade': None}
# {'_id': '50017283', 'Avg grade': None}
# {'_id': '50013016', 'Avg grade': None}
# {'_id': '40747050', 'Avg grade': None}
# {'_id': '41009192', 'Avg grade': None}
# {'_id': '41483883', 'Avg grade': None}
# {'_id': '50016982', 'Avg grade': None}
# {'_id': '41309940', 'Avg grade': None}
# {'_id': '41692582', 'Avg grade': None}
# {'_id': '50000983', 'Avg grade': None}
# {'_id': '50006579', 'Avg grade': None}
# {'_id': '41563476', 'Avg grade': None}
# {'_id': '41017592', 'Avg grade': None}
# {'_id': '50007361', 'Avg grade': None}
# {'_id': '41262792', 'Avg grade': None}
# {'_id': '50018279', 'Avg grade': None}
# {'_id': '40946431', 'Avg grade': None}
# {'_id': '50010502', 'Avg grade': None}
# {'_id': '40738008', 'Avg grade': None}
# {'_id': '50018734', 'Avg grade': None}
# {'_id': '41700793', 'Avg grade': None}
# {'_id': '41711304', 'Avg grade': None}
# {'_id': '50000249', 'Avg grade': None}
# {'_id': '50006264', 'Avg grade': None}
# {'_id': '40744238', 'Avg grade': None}
# {'_id': '50001488', 'Avg grade': None}
# {'_id': '40366396', 'Avg grade': None}
# {'_id': '41538001', 'Avg grade': None}
# {'_id': '40356151', 'Avg grade': None}
# {'_id': '40596359', 'Avg grade': None}
# {'_id': '41618382', 'Avg grade': None}
# {'_id': '41253241', 'Avg grade': None}
# {'_id': '40861141', 'Avg grade': None}
# {'_id': '41450361', 'Avg grade': None}
# {'_id': '40755548', 'Avg grade': None}
# {'_id': '41125776', 'Avg grade': None}
# {'_id': '41658484', 'Avg grade': None}
# {'_id': '41711586', 'Avg grade': None}
# {'_id': '50001454', 'Avg grade': None}
# {'_id': '41597042', 'Avg grade': None}
# {'_id': '50000412', 'Avg grade': None}
# {'_id': '41168585', 'Avg grade': None}
# {'_id': '41690830', 'Avg grade': None}
# {'_id': '41694705', 'Avg grade': None}
# {'_id': '41674655', 'Avg grade': None}
# {'_id': '50004895', 'Avg grade': None}
# {'_id': '50007157', 'Avg grade': None}
# {'_id': '41396603', 'Avg grade': None}
# {'_id': '50006173', 'Avg grade': None}
# {'_id': '40894333', 'Avg grade': None}
# {'_id': '41198475', 'Avg grade': None}
# {'_id': '50012282', 'Avg grade': None}
# {'_id': '50005758', 'Avg grade': None}
# {'_id': '50001108', 'Avg grade': None}
# {'_id': '50018530', 'Avg grade': None}
# {'_id': '40960987', 'Avg grade': None}
# {'_id': '41107658', 'Avg grade': None}
# {'_id': '41355901', 'Avg grade': None}
# {'_id': '50001778', 'Avg grade': None}
# {'_id': '41702145', 'Avg grade': None}
# {'_id': '41721390', 'Avg grade': None}
# {'_id': '41010943', 'Avg grade': None}
# {'_id': '50003545', 'Avg grade': None}
# {'_id': '50010767', 'Avg grade': None}
# {'_id': '40871006', 'Avg grade': None}
# {'_id': '50011701', 'Avg grade': None}
# {'_id': '50012467', 'Avg grade': None}
# {'_id': '50016167', 'Avg grade': None}
# {'_id': '50015317', 'Avg grade': None}
# {'_id': '41152741', 'Avg grade': None}
# {'_id': '40545071', 'Avg grade': None}
# {'_id': '41637092', 'Avg grade': None}
# {'_id': '50002639', 'Avg grade': None}
# {'_id': '40782042', 'Avg grade': None}
# {'_id': '41168603', 'Avg grade': None}
# {'_id': '41711697', 'Avg grade': None}
# {'_id': '50005660', 'Avg grade': None}
# {'_id': '50018165', 'Avg grade': None}
# {'_id': '41690734', 'Avg grade': None}
# {'_id': '50011825', 'Avg grade': None}
# {'_id': '40386428', 'Avg grade': None}
# {'_id': '41424585', 'Avg grade': None}
# {'_id': '41657119', 'Avg grade': None}
# {'_id': '41120866', 'Avg grade': None}
# {'_id': '41026002', 'Avg grade': None}
# {'_id': '50010263', 'Avg grade': None}
# {'_id': '41605848', 'Avg grade': None}
# {'_id': '40843676', 'Avg grade': None}
# {'_id': '50015090', 'Avg grade': None}
# {'_id': '41687904', 'Avg grade': None}
# {'_id': '50012178', 'Avg grade': None}
# {'_id': '40515702', 'Avg grade': None}
# {'_id': '41620087', 'Avg grade': None}
# {'_id': '40950278', 'Avg grade': None}
# {'_id': '50007607', 'Avg grade': None}
# {'_id': '41711425', 'Avg grade': None}
# {'_id': '41549174', 'Avg grade': None}
# {'_id': '50018588', 'Avg grade': None}
# {'_id': '40388194', 'Avg grade': None}
# {'_id': '50006813', 'Avg grade': None}
# {'_id': '40396126', 'Avg grade': None}
# {'_id': '41200687', 'Avg grade': None}
# {'_id': '41206905', 'Avg grade': None}
# {'_id': '50011368', 'Avg grade': None}
# {'_id': '41690369', 'Avg grade': None}
# {'_id': '50016215', 'Avg grade': None}
# {'_id': '41401794', 'Avg grade': None}
# {'_id': '41256363', 'Avg grade': None}
# {'_id': '40386069', 'Avg grade': None}
# {'_id': '41677059', 'Avg grade': None}
# {'_id': '40787040', 'Avg grade': None}
# {'_id': '41702496', 'Avg grade': None}
# {'_id': '50014098', 'Avg grade': None}
# {'_id': '40882663', 'Avg grade': None}
# {'_id': '40571696', 'Avg grade': None}
# {'_id': '40601738', 'Avg grade': None}
# {'_id': '41395422', 'Avg grade': None}
# {'_id': '41614771', 'Avg grade': None}
# {'_id': '41285514', 'Avg grade': None}
# {'_id': '41485148', 'Avg grade': None}
# {'_id': '41650342', 'Avg grade': None}
# {'_id': '50002081', 'Avg grade': None}
# {'_id': '50010783', 'Avg grade': None}
# {'_id': '50003438', 'Avg grade': None}
# {'_id': '40401810', 'Avg grade': None}
# {'_id': '41249550', 'Avg grade': None}
# {'_id': '41291319', 'Avg grade': None}
# {'_id': '40564701', 'Avg grade': None}
# {'_id': '50006149', 'Avg grade': None}
# {'_id': '50012807', 'Avg grade': None}
# {'_id': '41259230', 'Avg grade': None}
# {'_id': '41597207', 'Avg grade': None}
# {'_id': '50012945', 'Avg grade': None}
# {'_id': '41166914', 'Avg grade': None}
# {'_id': '41271971', 'Avg grade': None}
# {'_id': '40926286', 'Avg grade': None}
# {'_id': '41316784', 'Avg grade': None}
# {'_id': '41373803', 'Avg grade': None}
# {'_id': '41547860', 'Avg grade': None}
# {'_id': '41205974', 'Avg grade': None}
# {'_id': '41611875', 'Avg grade': None}
# {'_id': '41645852', 'Avg grade': None}
# {'_id': '50000456', 'Avg grade': None}
# {'_id': '50016780', 'Avg grade': None}
# {'_id': '50001986', 'Avg grade': None}
# {'_id': '41621477', 'Avg grade': None}
# {'_id': '40879245', 'Avg grade': None}
# {'_id': '41693533', 'Avg grade': None}
# {'_id': '41555685', 'Avg grade': None}
# {'_id': '41305837', 'Avg grade': None}
# {'_id': '41421031', 'Avg grade': None}
# {'_id': '41567009', 'Avg grade': None}
# {'_id': '41168206', 'Avg grade': None}
# {'_id': '41185693', 'Avg grade': None}
# {'_id': '41224979', 'Avg grade': None}
# {'_id': '41700112', 'Avg grade': None}
# {'_id': '50000720', 'Avg grade': None}
# {'_id': '41460035', 'Avg grade': None}
# {'_id': '40368207', 'Avg grade': None}
# {'_id': '50016605', 'Avg grade': None}
# {'_id': '41497492', 'Avg grade': None}
# {'_id': '41332050', 'Avg grade': None}
# {'_id': '41296066', 'Avg grade': None}
# {'_id': '40722597', 'Avg grade': None}
# {'_id': '41305288', 'Avg grade': None}
# {'_id': '41407455', 'Avg grade': None}
# {'_id': '50006135', 'Avg grade': None}
# {'_id': '50011704', 'Avg grade': None}
# {'_id': '41433965', 'Avg grade': None}
# {'_id': '40590969', 'Avg grade': None}
# {'_id': '41693307', 'Avg grade': None}
# {'_id': '50015168', 'Avg grade': None}
# {'_id': '50017288', 'Avg grade': None}
# {'_id': '41640234', 'Avg grade': None}
# {'_id': '41146939', 'Avg grade': None}
# {'_id': '41246308', 'Avg grade': None}
# {'_id': '41696986', 'Avg grade': None}
# {'_id': '41499986', 'Avg grade': None}
# {'_id': '50004830', 'Avg grade': None}
# {'_id': '41460759', 'Avg grade': None}
# {'_id': '41355257', 'Avg grade': None}
# {'_id': '40705438', 'Avg grade': None}
# {'_id': '41359698', 'Avg grade': None}
# {'_id': '41711427', 'Avg grade': None}
# {'_id': '41215164', 'Avg grade': None}
# {'_id': '50004931', 'Avg grade': None}
# {'_id': '41382947', 'Avg grade': None}
# {'_id': '41472216', 'Avg grade': None}
# {'_id': '50001526', 'Avg grade': None}
# {'_id': '50000021', 'Avg grade': None}
# {'_id': '41363485', 'Avg grade': None}
# {'_id': '41543996', 'Avg grade': None}
# {'_id': '41486672', 'Avg grade': None}
# {'_id': '41377918', 'Avg grade': None}
# {'_id': '41150133', 'Avg grade': None}
# {'_id': '50002734', 'Avg grade': None}
# {'_id': '41583431', 'Avg grade': None}
# {'_id': '50002889', 'Avg grade': None}
# {'_id': '41262369', 'Avg grade': None}
# {'_id': '41423445', 'Avg grade': None}
# {'_id': '41453516', 'Avg grade': None}
# {'_id': '41169998', 'Avg grade': None}
# {'_id': '50000845', 'Avg grade': None}
# {'_id': '50004352', 'Avg grade': None}
# {'_id': '50003072', 'Avg grade': None}
# {'_id': '50005556', 'Avg grade': None}
# {'_id': '50006441', 'Avg grade': None}
# {'_id': '50002203', 'Avg grade': None}
# {'_id': '50014339', 'Avg grade': None}
# {'_id': '50003720', 'Avg grade': None}
# {'_id': '50018297', 'Avg grade': None}
# {'_id': '40368346', 'Avg grade': None}
# {'_id': '41424484', 'Avg grade': None}
# {'_id': '50002342', 'Avg grade': None}
# {'_id': '41195346', 'Avg grade': None}
# {'_id': '41498627', 'Avg grade': None}
# {'_id': '41372259', 'Avg grade': None}
# {'_id': '41601422', 'Avg grade': None}
# {'_id': '40721121', 'Avg grade': None}
# {'_id': '50005254', 'Avg grade': None}
# {'_id': '50017257', 'Avg grade': None}
# {'_id': '50018753', 'Avg grade': None}
# {'_id': '40922528', 'Avg grade': None}
# {'_id': '41540924', 'Avg grade': None}
# {'_id': '41701643', 'Avg grade': None}
# {'_id': '40647590', 'Avg grade': None}
# {'_id': '41603124', 'Avg grade': None}
# {'_id': '50004889', 'Avg grade': None}
# {'_id': '50017292', 'Avg grade': None}
# {'_id': '50002695', 'Avg grade': None}
# {'_id': '50017284', 'Avg grade': None}
# {'_id': '41656235', 'Avg grade': None}
# {'_id': '40799399', 'Avg grade': None}
# {'_id': '41632066', 'Avg grade': None}
# {'_id': '41086204', 'Avg grade': None}
# {'_id': '41617019', 'Avg grade': None}
# {'_id': '40369213', 'Avg grade': None}
# {'_id': '41702488', 'Avg grade': None}
# {'_id': '41305454', 'Avg grade': None}
# {'_id': '41453335', 'Avg grade': None}
# {'_id': '41435736', 'Avg grade': None}
# {'_id': '41416298', 'Avg grade': None}
# {'_id': '41611720', 'Avg grade': None}
# {'_id': '40788888', 'Avg grade': None}
# {'_id': '40863575', 'Avg grade': None}
# {'_id': '50006972', 'Avg grade': None}
# {'_id': '41485041', 'Avg grade': None}
# {'_id': '41515868', 'Avg grade': None}
# {'_id': '41518767', 'Avg grade': None}
# {'_id': '41585056', 'Avg grade': None}
# {'_id': '50003143', 'Avg grade': None}
# {'_id': '50008234', 'Avg grade': None}
# {'_id': '40403917', 'Avg grade': None}
# {'_id': '41567407', 'Avg grade': None}
# {'_id': '50002242', 'Avg grade': None}
# {'_id': '50008995', 'Avg grade': None}
# {'_id': '41534162', 'Avg grade': None}
# {'_id': '41570059', 'Avg grade': None}
# {'_id': '40748671', 'Avg grade': None}
# {'_id': '41462262', 'Avg grade': None}
# {'_id': '41476734', 'Avg grade': None}
# {'_id': '41322705', 'Avg grade': None}
# {'_id': '41682709', 'Avg grade': None}
# {'_id': '50002604', 'Avg grade': None}
# {'_id': '50003860', 'Avg grade': None}
# {'_id': '50015183', 'Avg grade': None}
# {'_id': '41692661', 'Avg grade': None}
# {'_id': '41567796', 'Avg grade': None}
# {'_id': '50017426', 'Avg grade': None}
# {'_id': '41376524', 'Avg grade': None}
# {'_id': '50018977', 'Avg grade': None}
# {'_id': '40394164', 'Avg grade': None}
# {'_id': '41447431', 'Avg grade': None}
# {'_id': '40975524', 'Avg grade': None}
# {'_id': '41073979', 'Avg grade': None}
# {'_id': '41574300', 'Avg grade': None}
# {'_id': '41602382', 'Avg grade': None}
# {'_id': '50003842', 'Avg grade': None}
# {'_id': '41568374', 'Avg grade': None}
# {'_id': '50003253', 'Avg grade': None}
# {'_id': '41636692', 'Avg grade': None}
# {'_id': '41640137', 'Avg grade': None}
# {'_id': '41651838', 'Avg grade': None}
# {'_id': '50002534', 'Avg grade': None}
# {'_id': '50005589', 'Avg grade': None}
# {'_id': '50009526', 'Avg grade': None}
# {'_id': '50010346', 'Avg grade': None}
# {'_id': '50012113', 'Avg grade': None}
# {'_id': '50013145', 'Avg grade': None}
# {'_id': '40391534', 'Avg grade': None}
# {'_id': '50014318', 'Avg grade': None}
# {'_id': '41292988', 'Avg grade': None}
# {'_id': '41140991', 'Avg grade': None}
# {'_id': '41703233', 'Avg grade': None}
# {'_id': '41444322', 'Avg grade': None}
# {'_id': '41540064', 'Avg grade': None}
# {'_id': '41463547', 'Avg grade': None}
# {'_id': '41541993', 'Avg grade': None}
# {'_id': '41247222', 'Avg grade': None}
# {'_id': '41557354', 'Avg grade': None}
# {'_id': '40400652', 'Avg grade': None}
# {'_id': '41412002', 'Avg grade': None}
# {'_id': '41605126', 'Avg grade': None}
# {'_id': '41695013', 'Avg grade': None}
# {'_id': '50003712', 'Avg grade': None}
# {'_id': '41564898', 'Avg grade': None}
# {'_id': '50011600', 'Avg grade': None}
# {'_id': '41266242', 'Avg grade': None}
# {'_id': '41403222', 'Avg grade': None}
# {'_id': '40982677', 'Avg grade': None}
# {'_id': '41715646', 'Avg grade': None}
# {'_id': '41313209', 'Avg grade': None}
# {'_id': '41674622', 'Avg grade': None}
# {'_id': '50018249', 'Avg grade': None}
# {'_id': '41258881', 'Avg grade': None}
# {'_id': '40393038', 'Avg grade': None}
# {'_id': '50008621', 'Avg grade': None}
# {'_id': '40376031', 'Avg grade': None}
# {'_id': '41556815', 'Avg grade': None}
# {'_id': '41650923', 'Avg grade': None}
# {'_id': '40718665', 'Avg grade': None}
# {'_id': '41068439', 'Avg grade': None}
# {'_id': '41117663', 'Avg grade': None}
# {'_id': '41710546', 'Avg grade': None}
# {'_id': '40584813', 'Avg grade': None}
# {'_id': '40878403', 'Avg grade': None}
# {'_id': '41347049', 'Avg grade': None}
# {'_id': '41264529', 'Avg grade': None}
# {'_id': '50002238', 'Avg grade': None}
# {'_id': '50018683', 'Avg grade': None}
# {'_id': '50009844', 'Avg grade': None}
# {'_id': '40951884', 'Avg grade': None}
# {'_id': '41044394', 'Avg grade': None}
# {'_id': '41688234', 'Avg grade': None}
# {'_id': '41523665', 'Avg grade': None}
# {'_id': '41457842', 'Avg grade': None}
# {'_id': '50014905', 'Avg grade': None}
# {'_id': '41098122', 'Avg grade': None}
# {'_id': '41141976', 'Avg grade': None}
# {'_id': '41362845', 'Avg grade': None}
# {'_id': '41199571', 'Avg grade': None}
# {'_id': '41241694', 'Avg grade': None}
# {'_id': '41254605', 'Avg grade': None}
# {'_id': '41635367', 'Avg grade': None}
# {'_id': '50000068', 'Avg grade': None}
# {'_id': '40972083', 'Avg grade': None}
# {'_id': '40983133', 'Avg grade': None}
# {'_id': '40967188', 'Avg grade': None}
# {'_id': '41177118', 'Avg grade': None}
# {'_id': '41493707', 'Avg grade': None}
# {'_id': '40948000', 'Avg grade': None}
# {'_id': '41719505', 'Avg grade': None}
# {'_id': '40395071', 'Avg grade': None}
# {'_id': '40951901', 'Avg grade': None}
# {'_id': '40942342', 'Avg grade': None}
# {'_id': '41704868', 'Avg grade': None}
# {'_id': '40394555', 'Avg grade': None}
# {'_id': '40800339', 'Avg grade': None}
# {'_id': '41269424', 'Avg grade': None}
# {'_id': '40877857', 'Avg grade': None}
# {'_id': '41430576', 'Avg grade': None}
# {'_id': '50004311', 'Avg grade': None}
# {'_id': '41271454', 'Avg grade': None}
# {'_id': '50011690', 'Avg grade': None}
# {'_id': '41611253', 'Avg grade': None}
# {'_id': '50018462', 'Avg grade': None}
# {'_id': '50001211', 'Avg grade': None}
# {'_id': '50002329', 'Avg grade': None}
# {'_id': '41243875', 'Avg grade': None}
# {'_id': '50001827', 'Avg grade': None}
# {'_id': '50004313', 'Avg grade': None}
# {'_id': '50008729', 'Avg grade': None}
# {'_id': '50015625', 'Avg grade': None}
# {'_id': '41278894', 'Avg grade': None}
# {'_id': '41031150', 'Avg grade': None}
# {'_id': '41434246', 'Avg grade': None}
# {'_id': '50017285', 'Avg grade': None}
# {'_id': '50009621', 'Avg grade': None}
# {'_id': '50017463', 'Avg grade': None}
# {'_id': '50011130', 'Avg grade': None}
# {'_id': '40387876', 'Avg grade': None}
# {'_id': '40846843', 'Avg grade': None}
# {'_id': '41080138', 'Avg grade': None}
# {'_id': '41381962', 'Avg grade': None}
# {'_id': '41704021', 'Avg grade': None}
# {'_id': '41548686', 'Avg grade': None}
# {'_id': '50004928', 'Avg grade': None}
# {'_id': '50011550', 'Avg grade': None}
# {'_id': '41719645', 'Avg grade': None}
# {'_id': '41181265', 'Avg grade': None}
# {'_id': '41318150', 'Avg grade': None}
# {'_id': '41585457', 'Avg grade': None}
# {'_id': '50006083', 'Avg grade': None}
# {'_id': '41697389', 'Avg grade': None}
# {'_id': '41696569', 'Avg grade': None}
# {'_id': '40390241', 'Avg grade': None}
# {'_id': '40987704', 'Avg grade': None}
# {'_id': '41100006', 'Avg grade': None}
# {'_id': '40394957', 'Avg grade': None}
# {'_id': '41331777', 'Avg grade': None}
# {'_id': '41647380', 'Avg grade': None}
# {'_id': '50002519', 'Avg grade': None}
# {'_id': '50001696', 'Avg grade': None}
# {'_id': '40998581', 'Avg grade': None}
# {'_id': '50007220', 'Avg grade': None}
# {'_id': '50011613', 'Avg grade': None}
# {'_id': '50017441', 'Avg grade': None}
# {'_id': '41289484', 'Avg grade': None}
# {'_id': '41394528', 'Avg grade': None}
# {'_id': '50016219', 'Avg grade': None}
# {'_id': '41566403', 'Avg grade': None}
# {'_id': '40980377', 'Avg grade': None}
# {'_id': '50010069', 'Avg grade': None}
# {'_id': '50017797', 'Avg grade': None}
# {'_id': '40385580', 'Avg grade': None}
# {'_id': '41674140', 'Avg grade': None}
# {'_id': '41315226', 'Avg grade': None}
# {'_id': '50009239', 'Avg grade': None}
# {'_id': '41126158', 'Avg grade': None}
# {'_id': '41337371', 'Avg grade': None}
# {'_id': '50018456', 'Avg grade': None}
# {'_id': '40402011', 'Avg grade': None}
# {'_id': '40397780', 'Avg grade': None}
# {'_id': '40674684', 'Avg grade': None}
# {'_id': '40938384', 'Avg grade': None}
# {'_id': '41089835', 'Avg grade': None}
# {'_id': '40369012', 'Avg grade': None}
# {'_id': '41502955', 'Avg grade': None}
# {'_id': '41156294', 'Avg grade': None}
# {'_id': '40386515', 'Avg grade': None}
# {'_id': '41662825', 'Avg grade': None}
# {'_id': '41695882', 'Avg grade': None}
# {'_id': '41139263', 'Avg grade': None}
# {'_id': '50002245', 'Avg grade': None}
# {'_id': '41539994', 'Avg grade': None}
# {'_id': '50017675', 'Avg grade': None}
# {'_id': '41365576', 'Avg grade': None}
# {'_id': '41547596', 'Avg grade': None}
# {'_id': '41638553', 'Avg grade': None}
# {'_id': '40804423', 'Avg grade': None}
# {'_id': '41549891', 'Avg grade': None}
# {'_id': '41016585', 'Avg grade': None}
# {'_id': '40382455', 'Avg grade': None}
# {'_id': '41552204', 'Avg grade': None}
# {'_id': '50004276', 'Avg grade': None}
# {'_id': '41485869', 'Avg grade': None}
# {'_id': '40849580', 'Avg grade': None}
# {'_id': '41229111', 'Avg grade': None}
# {'_id': '41630124', 'Avg grade': None}
# {'_id': '50009222', 'Avg grade': None}
# {'_id': '41717279', 'Avg grade': None}
# {'_id': '41502172', 'Avg grade': None}
# {'_id': '50002343', 'Avg grade': None}
# {'_id': '40733386', 'Avg grade': None}
# {'_id': '41474984', 'Avg grade': None}
# {'_id': '40950312', 'Avg grade': None}
# {'_id': '41388485', 'Avg grade': None}
# {'_id': '50016822', 'Avg grade': None}
# {'_id': '41242376', 'Avg grade': None}
# {'_id': '50017371', 'Avg grade': None}
# {'_id': '41273802', 'Avg grade': None}
# {'_id': '41376199', 'Avg grade': None}
# {'_id': '40380996', 'Avg grade': None}
# {'_id': '41039214', 'Avg grade': None}
# {'_id': '41545641', 'Avg grade': None}
# {'_id': '41641302', 'Avg grade': None}
# {'_id': '41548763', 'Avg grade': None}
# {'_id': '40747192', 'Avg grade': None}
# {'_id': '41236893', 'Avg grade': None}
# {'_id': '50000034', 'Avg grade': None}
# {'_id': '41087832', 'Avg grade': None}
# {'_id': '41388869', 'Avg grade': None}
# {'_id': '41425555', 'Avg grade': None}
# {'_id': '40391658', 'Avg grade': None}
# {'_id': '41621561', 'Avg grade': None}
# {'_id': '40391383', 'Avg grade': None}
# {'_id': '41291187', 'Avg grade': None}
# {'_id': '41569824', 'Avg grade': None}
# {'_id': '50010070', 'Avg grade': None}
# {'_id': '41287433', 'Avg grade': None}
# {'_id': '41542863', 'Avg grade': None}
# {'_id': '40722176', 'Avg grade': None}
# {'_id': '41635318', 'Avg grade': None}
# {'_id': '40367481', 'Avg grade': None}
# {'_id': '41182682', 'Avg grade': None}
# {'_id': '50013242', 'Avg grade': None}
# {'_id': '41379274', 'Avg grade': None}
# {'_id': '41005330', 'Avg grade': None}
# {'_id': '41157671', 'Avg grade': None}
# {'_id': '41015300', 'Avg grade': None}
# {'_id': '41652507', 'Avg grade': None}
# {'_id': '41057286', 'Avg grade': None}
# {'_id': '50001029', 'Avg grade': None}
# {'_id': '50003715', 'Avg grade': None}
# {'_id': '40403880', 'Avg grade': None}
# {'_id': '40400957', 'Avg grade': None}
# {'_id': '40579607', 'Avg grade': None}
# {'_id': '40858878', 'Avg grade': None}
# {'_id': '41366534', 'Avg grade': None}
# {'_id': '41582081', 'Avg grade': None}
# {'_id': '41665068', 'Avg grade': None}
# {'_id': '40599004', 'Avg grade': None}
# {'_id': '41226387', 'Avg grade': None}
# {'_id': '50008665', 'Avg grade': None}
# {'_id': '50010699', 'Avg grade': None}
# {'_id': '41450634', 'Avg grade': None}
# {'_id': '50015422', 'Avg grade': None}
# {'_id': '50017486', 'Avg grade': None}
# {'_id': '50009855', 'Avg grade': None}
# {'_id': '41632836', 'Avg grade': None}
# {'_id': '40386102', 'Avg grade': None}
# {'_id': '41417111', 'Avg grade': None}
# {'_id': '41223822', 'Avg grade': None}
# {'_id': '50011370', 'Avg grade': None}
# {'_id': '50011434', 'Avg grade': None}
# {'_id': '41720134', 'Avg grade': None}
# {'_id': '50014747', 'Avg grade': None}
# {'_id': '41246771', 'Avg grade': None}
# {'_id': '40899767', 'Avg grade': None}
# {'_id': '40397810', 'Avg grade': None}
# {'_id': '50011688', 'Avg grade': None}
# {'_id': '41005152', 'Avg grade': None}
# {'_id': '41023988', 'Avg grade': None}
# {'_id': '41699717', 'Avg grade': None}
# {'_id': '41290116', 'Avg grade': None}
# {'_id': '41196536', 'Avg grade': None}
# {'_id': '40883740', 'Avg grade': None}
# {'_id': '41061016', 'Avg grade': None}
# {'_id': '41013968', 'Avg grade': None}
# {'_id': '41511548', 'Avg grade': None}
# {'_id': '41543343', 'Avg grade': None}
# {'_id': '41368836', 'Avg grade': None}
# {'_id': '50005311', 'Avg grade': None}
# {'_id': '50015892', 'Avg grade': None}
# {'_id': '40946043', 'Avg grade': None}
# {'_id': '40995563', 'Avg grade': None}
# {'_id': '41536221', 'Avg grade': None}
# {'_id': '41665851', 'Avg grade': None}
# {'_id': '50015486', 'Avg grade': None}
# {'_id': '41702601', 'Avg grade': None}
# {'_id': '50012527', 'Avg grade': None}
# {'_id': '40365288', 'Avg grade': None}
# {'_id': '50017972', 'Avg grade': None}
# {'_id': '40365499', 'Avg grade': None}
# {'_id': '40385852', 'Avg grade': None}
# {'_id': '41320212', 'Avg grade': None}
# {'_id': '41265421', 'Avg grade': None}
# {'_id': '41701040', 'Avg grade': None}
# {'_id': '50007596', 'Avg grade': None}
# {'_id': '41589440', 'Avg grade': None}
# {'_id': '50003561', 'Avg grade': None}
# {'_id': '50012085', 'Avg grade': None}
# {'_id': '50016055', 'Avg grade': None}
# {'_id': '40369139', 'Avg grade': None}
# {'_id': '41155680', 'Avg grade': None}
# {'_id': '41592433', 'Avg grade': None}
# {'_id': '41063201', 'Avg grade': None}
# {'_id': '40551996', 'Avg grade': None}
# {'_id': '41180953', 'Avg grade': None}
# {'_id': '50008540', 'Avg grade': None}
# {'_id': '41366074', 'Avg grade': None}
# {'_id': '41551464', 'Avg grade': None}
# {'_id': '41719015', 'Avg grade': None}
# {'_id': '40999287', 'Avg grade': None}
# {'_id': '41497700', 'Avg grade': None}
# {'_id': '41579518', 'Avg grade': None}
# {'_id': '41366281', 'Avg grade': None}
# {'_id': '41477087', 'Avg grade': None}
# {'_id': '41485907', 'Avg grade': None}
# {'_id': '40811162', 'Avg grade': None}
# {'_id': '41547507', 'Avg grade': None}
# {'_id': '40376495', 'Avg grade': None}
# {'_id': '41519888', 'Avg grade': None}
# {'_id': '41611708', 'Avg grade': None}
# {'_id': '40972759', 'Avg grade': None}
# {'_id': '41704402', 'Avg grade': None}
# {'_id': '41579281', 'Avg grade': None}
# {'_id': '41716441', 'Avg grade': None}
# {'_id': '50000134', 'Avg grade': None}
# {'_id': '50001036', 'Avg grade': None}
# {'_id': '50018023', 'Avg grade': None}
# {'_id': '40673275', 'Avg grade': None}
# {'_id': '41557498', 'Avg grade': None}
# {'_id': '41303456', 'Avg grade': None}
# {'_id': '50018445', 'Avg grade': None}
# {'_id': '41222982', 'Avg grade': None}
# {'_id': '50008913', 'Avg grade': None}
# {'_id': '50004464', 'Avg grade': None}
# {'_id': '41231920', 'Avg grade': None}
# {'_id': '41638047', 'Avg grade': None}
# {'_id': '50011060', 'Avg grade': None}
# {'_id': '50013837', 'Avg grade': None}
# {'_id': '41413135', 'Avg grade': None}
# {'_id': '41652004', 'Avg grade': None}
# {'_id': '41566831', 'Avg grade': None}
# {'_id': '40563475', 'Avg grade': None}
# {'_id': '50009217', 'Avg grade': None}
# {'_id': '41618402', 'Avg grade': None}
# {'_id': '41631790', 'Avg grade': None}
# {'_id': '40367570', 'Avg grade': None}
# {'_id': '41482609', 'Avg grade': None}
# {'_id': '41371823', 'Avg grade': None}
# {'_id': '41714411', 'Avg grade': None}
# {'_id': '40607093', 'Avg grade': None}
# {'_id': '41395934', 'Avg grade': None}
# {'_id': '40380657', 'Avg grade': None}
# {'_id': '41710627', 'Avg grade': None}
# {'_id': '41680107', 'Avg grade': None}
# {'_id': '50013395', 'Avg grade': None}
# {'_id': '40587376', 'Avg grade': None}
# {'_id': '41255465', 'Avg grade': None}
# {'_id': '40989294', 'Avg grade': None}
# {'_id': '50017843', 'Avg grade': None}
# {'_id': '40620427', 'Avg grade': None}
# {'_id': '50001049', 'Avg grade': None}
# {'_id': '41488326', 'Avg grade': None}
# {'_id': '41507697', 'Avg grade': None}
# {'_id': '41202545', 'Avg grade': None}
# {'_id': '40728353', 'Avg grade': None}
# {'_id': '41117938', 'Avg grade': None}
# {'_id': '41628343', 'Avg grade': None}
# {'_id': '41685731', 'Avg grade': None}
# {'_id': '41255592', 'Avg grade': None}
# {'_id': '41645443', 'Avg grade': None}
# {'_id': '40698807', 'Avg grade': None}
# {'_id': '41346086', 'Avg grade': None}
# {'_id': '41446201', 'Avg grade': None}
# {'_id': '41534535', 'Avg grade': None}
# {'_id': '41701495', 'Avg grade': None}
# {'_id': '40931927', 'Avg grade': None}
# {'_id': '41540996', 'Avg grade': None}
# {'_id': '50018820', 'Avg grade': None}
# {'_id': '41466918', 'Avg grade': None}
# {'_id': '41659448', 'Avg grade': None}
# {'_id': '41703181', 'Avg grade': None}
# {'_id': '50001985', 'Avg grade': None}
# {'_id': '50000910', 'Avg grade': None}
# {'_id': '41516054', 'Avg grade': None}
# {'_id': '41345374', 'Avg grade': None}
# {'_id': '41430526', 'Avg grade': None}
# {'_id': '41691907', 'Avg grade': None}
# {'_id': '41502571', 'Avg grade': None}
# {'_id': '41573942', 'Avg grade': None}
# {'_id': '41463474', 'Avg grade': None}
# {'_id': '40395826', 'Avg grade': None}
# {'_id': '40601883', 'Avg grade': None}
# {'_id': '40829150', 'Avg grade': None}
# {'_id': '41200936', 'Avg grade': None}
# {'_id': '41650543', 'Avg grade': None}
# {'_id': '41421789', 'Avg grade': None}
# {'_id': '40388392', 'Avg grade': None}
# {'_id': '41690772', 'Avg grade': None}
# {'_id': '41701102', 'Avg grade': None}
# {'_id': '41245474', 'Avg grade': None}
# {'_id': '40483729', 'Avg grade': None}
# {'_id': '50008189', 'Avg grade': None}
# {'_id': '50016283', 'Avg grade': None}
# {'_id': '41288910', 'Avg grade': None}
# {'_id': '41395533', 'Avg grade': None}
# {'_id': '41571471', 'Avg grade': None}
# {'_id': '50012794', 'Avg grade': None}
# {'_id': '50013293', 'Avg grade': None}
# {'_id': '50017902', 'Avg grade': None}
# {'_id': '50008346', 'Avg grade': None}
# {'_id': '41444679', 'Avg grade': None}
# {'_id': '50009033', 'Avg grade': None}
# {'_id': '41553284', 'Avg grade': None}
# {'_id': '41710766', 'Avg grade': None}
# {'_id': '41711533', 'Avg grade': None}
# {'_id': '50005085', 'Avg grade': None}
# {'_id': '40370150', 'Avg grade': None}
# {'_id': '41158108', 'Avg grade': None}
# {'_id': '41721425', 'Avg grade': None}
# {'_id': '41052939', 'Avg grade': None}
# {'_id': '41673115', 'Avg grade': None}
# {'_id': '50001330', 'Avg grade': None}
# {'_id': '41696743', 'Avg grade': None}
# {'_id': '50002071', 'Avg grade': None}
# {'_id': '41046488', 'Avg grade': None}
# {'_id': '41389547', 'Avg grade': None}
# {'_id': '41573267', 'Avg grade': None}
# {'_id': '50011303', 'Avg grade': None}
# {'_id': '40939600', 'Avg grade': None}
# {'_id': '41178622', 'Avg grade': None}
# {'_id': '41680111', 'Avg grade': None}
# {'_id': '40599302', 'Avg grade': None}
# {'_id': '41089522', 'Avg grade': None}
# {'_id': '41478688', 'Avg grade': None}
# {'_id': '41644006', 'Avg grade': None}
# {'_id': '50017969', 'Avg grade': None}
# {'_id': '40700181', 'Avg grade': None}
# {'_id': '40743421', 'Avg grade': None}
# {'_id': '50015981', 'Avg grade': None}
# {'_id': '41473278', 'Avg grade': None}
# {'_id': '41606387', 'Avg grade': None}
# {'_id': '41614718', 'Avg grade': None}
# {'_id': '41708744', 'Avg grade': None}
# {'_id': '40601696', 'Avg grade': None}
# {'_id': '41253389', 'Avg grade': None}
# {'_id': '40522372', 'Avg grade': None}
# {'_id': '50016237', 'Avg grade': None}
# {'_id': '41660323', 'Avg grade': None}
# {'_id': '50007077', 'Avg grade': None}
# {'_id': '41461341', 'Avg grade': None}
# {'_id': '40997706', 'Avg grade': None}
# {'_id': '41479400', 'Avg grade': None}
# {'_id': '41403890', 'Avg grade': None}
# {'_id': '41264671', 'Avg grade': None}
# {'_id': '41299756', 'Avg grade': None}
# {'_id': '41386849', 'Avg grade': None}
# {'_id': '41565257', 'Avg grade': None}
# {'_id': '41695128', 'Avg grade': None}
# {'_id': '40374268', 'Avg grade': None}
# {'_id': '40399174', 'Avg grade': None}
# {'_id': '41018400', 'Avg grade': None}
# {'_id': '41543356', 'Avg grade': None}
# {'_id': '41707090', 'Avg grade': None}
# {'_id': '41511273', 'Avg grade': None}
# {'_id': '41056159', 'Avg grade': None}
# {'_id': '41709412', 'Avg grade': None}
# {'_id': '50013983', 'Avg grade': None}
# {'_id': '50015252', 'Avg grade': None}
# {'_id': '50015385', 'Avg grade': None}
# {'_id': '41168203', 'Avg grade': None}
# {'_id': '41318674', 'Avg grade': None}
# {'_id': '50001457', 'Avg grade': None}
# {'_id': '41449421', 'Avg grade': None}
# {'_id': '40663005', 'Avg grade': None}
# {'_id': '50000280', 'Avg grade': None}
# {'_id': '41227024', 'Avg grade': None}
# {'_id': '41075909', 'Avg grade': None}
# {'_id': '41514595', 'Avg grade': None}
# {'_id': '40876472', 'Avg grade': None}
# {'_id': '41642195', 'Avg grade': None}
# {'_id': '50011799', 'Avg grade': None}
# {'_id': '50014021', 'Avg grade': None}
# {'_id': '41525010', 'Avg grade': None}
# {'_id': '41543033', 'Avg grade': None}
# {'_id': '50015958', 'Avg grade': None}
# {'_id': '41532069', 'Avg grade': None}
# {'_id': '41702607', 'Avg grade': None}
# {'_id': '40585407', 'Avg grade': None}
# {'_id': '50018511', 'Avg grade': None}
# {'_id': '41445662', 'Avg grade': None}
# {'_id': '41056253', 'Avg grade': None}
# {'_id': '41011682', 'Avg grade': None}
# {'_id': '41157974', 'Avg grade': None}
# {'_id': '41716268', 'Avg grade': None}
# {'_id': '40365361', 'Avg grade': None}
# {'_id': '41468815', 'Avg grade': None}
# {'_id': '41596018', 'Avg grade': None}
# {'_id': '41594825', 'Avg grade': None}
# {'_id': '50017976', 'Avg grade': None}
# {'_id': '50018236', 'Avg grade': None}
# {'_id': '50002447', 'Avg grade': None}
# {'_id': '50007239', 'Avg grade': None}
# {'_id': '50018368', 'Avg grade': None}
# {'_id': '40394449', 'Avg grade': None}
# {'_id': '41241636', 'Avg grade': None}
# {'_id': '41020235', 'Avg grade': None}
# {'_id': '40864834', 'Avg grade': None}
# {'_id': '41094459', 'Avg grade': None}
# {'_id': '40575255', 'Avg grade': None}
# {'_id': '41148105', 'Avg grade': None}
# {'_id': '50006796', 'Avg grade': None}
# {'_id': '50016802', 'Avg grade': None}
# {'_id': '40945328', 'Avg grade': None}
# {'_id': '50000805', 'Avg grade': None}
# {'_id': '40387027', 'Avg grade': None}
# {'_id': '41688672', 'Avg grade': None}
# {'_id': '41360136', 'Avg grade': None}
# {'_id': '41596385', 'Avg grade': None}
# {'_id': '50004782', 'Avg grade': None}
# {'_id': '50005642', 'Avg grade': None}
# {'_id': '41676526', 'Avg grade': None}
# {'_id': '41716315', 'Avg grade': None}
# {'_id': '50010756', 'Avg grade': None}
# {'_id': '50016536', 'Avg grade': None}
# {'_id': '50016752', 'Avg grade': None}
# {'_id': '41160401', 'Avg grade': None}
# {'_id': '50017221', 'Avg grade': None}
# {'_id': '50018870', 'Avg grade': None}
# {'_id': '50010018', 'Avg grade': None}
# {'_id': '41297989', 'Avg grade': None}
# {'_id': '50007858', 'Avg grade': None}
# {'_id': '41570217', 'Avg grade': None}
# {'_id': '50017782', 'Avg grade': None}
# {'_id': '40398561', 'Avg grade': None}
# {'_id': '41445447', 'Avg grade': None}
# {'_id': '41602559', 'Avg grade': None}
# {'_id': '41711177', 'Avg grade': None}
# {'_id': '40831779', 'Avg grade': None}
# {'_id': '41129350', 'Avg grade': None}
# {'_id': '41645519', 'Avg grade': None}
# {'_id': '50016209', 'Avg grade': None}
# {'_id': '40966724', 'Avg grade': None}
# {'_id': '41396679', 'Avg grade': None}
# {'_id': '50012378', 'Avg grade': None}
# {'_id': '41523649', 'Avg grade': None}
# {'_id': '41321758', 'Avg grade': None}
# {'_id': '50012674', 'Avg grade': None}
# {'_id': '40586454', 'Avg grade': None}
# {'_id': '41538516', 'Avg grade': None}
# {'_id': '50003489', 'Avg grade': None}
# {'_id': '41489181', 'Avg grade': None}
# {'_id': '41302020', 'Avg grade': None}
# {'_id': '41588040', 'Avg grade': None}
# {'_id': '41619708', 'Avg grade': None}
# {'_id': '41708930', 'Avg grade': None}
# {'_id': '50002139', 'Avg grade': None}
# {'_id': '40399279', 'Avg grade': None}
# {'_id': '40705931', 'Avg grade': None}
# {'_id': '50005669', 'Avg grade': None}
# {'_id': '50010814', 'Avg grade': None}
# {'_id': '40815627', 'Avg grade': None}
# {'_id': '50018760', 'Avg grade': None}
# {'_id': '40374088', 'Avg grade': None}
# {'_id': '40988754', 'Avg grade': None}
# {'_id': '50005469', 'Avg grade': None}
# {'_id': '50010702', 'Avg grade': None}
# {'_id': '50001823', 'Avg grade': None}
# {'_id': '40513031', 'Avg grade': None}
# {'_id': '41505961', 'Avg grade': None}
# {'_id': '40392141', 'Avg grade': None}
# {'_id': '50001589', 'Avg grade': None}
# {'_id': '41519688', 'Avg grade': None}
# {'_id': '41550593', 'Avg grade': None}
# {'_id': '41468049', 'Avg grade': None}
# {'_id': '41169052', 'Avg grade': None}
# {'_id': '41304618', 'Avg grade': None}
# {'_id': '41644068', 'Avg grade': None}
# {'_id': '50003887', 'Avg grade': None}
# {'_id': '41556592', 'Avg grade': None}
# {'_id': '50004455', 'Avg grade': None}
# {'_id': '50006043', 'Avg grade': None}
# {'_id': '50011479', 'Avg grade': None}
# {'_id': '41300619', 'Avg grade': None}
# {'_id': '41304245', 'Avg grade': None}
# {'_id': '41560775', 'Avg grade': None}
# {'_id': '41379322', 'Avg grade': None}
# {'_id': '41422211', 'Avg grade': None}
# {'_id': '50011079', 'Avg grade': None}
# {'_id': '41462642', 'Avg grade': None}
# {'_id': '41596415', 'Avg grade': None}
# {'_id': '41693508', 'Avg grade': None}
# {'_id': '50002099', 'Avg grade': None}
# {'_id': '41443150', 'Avg grade': None}
# {'_id': '41406893', 'Avg grade': None}
# {'_id': '41389443', 'Avg grade': None}
# {'_id': '40571587', 'Avg grade': None}
# {'_id': '41504915', 'Avg grade': None}
# {'_id': '41304224', 'Avg grade': None}
# {'_id': '41133094', 'Avg grade': None}
# {'_id': '41612180', 'Avg grade': None}
# {'_id': '41420644', 'Avg grade': None}
# {'_id': '41448381', 'Avg grade': None}
# {'_id': '41719175', 'Avg grade': None}
# {'_id': '50011892', 'Avg grade': None}
# {'_id': '40383799', 'Avg grade': None}
# {'_id': '50005594', 'Avg grade': None}
# {'_id': '41624198', 'Avg grade': None}
# {'_id': '40668410', 'Avg grade': None}
# {'_id': '50017954', 'Avg grade': None}
# {'_id': '50008749', 'Avg grade': None}
# {'_id': '50018386', 'Avg grade': None}
# {'_id': '50018885', 'Avg grade': None}
# {'_id': '41575815', 'Avg grade': None}
# {'_id': '40401543', 'Avg grade': None}
# {'_id': '50016920', 'Avg grade': None}
# {'_id': '50015042', 'Avg grade': None}
# {'_id': '41345303', 'Avg grade': None}
# {'_id': '41001788', 'Avg grade': None}
# {'_id': '41393113', 'Avg grade': None}
# {'_id': '41694393', 'Avg grade': None}
# {'_id': '50011324', 'Avg grade': None}
# {'_id': '41395061', 'Avg grade': None}
# {'_id': '41436366', 'Avg grade': None}
# {'_id': '41000697', 'Avg grade': None}
# {'_id': '40511852', 'Avg grade': None}
# {'_id': '41008388', 'Avg grade': None}
# {'_id': '41327462', 'Avg grade': None}
# {'_id': '40958136', 'Avg grade': None}
# {'_id': '41297057', 'Avg grade': None}
# {'_id': '41391116', 'Avg grade': None}
# {'_id': '41694691', 'Avg grade': None}
# {'_id': '41702073', 'Avg grade': None}
# {'_id': '50009015', 'Avg grade': None}
# {'_id': '40982266', 'Avg grade': None}
# {'_id': '50012221', 'Avg grade': None}
# {'_id': '40589545', 'Avg grade': None}
# {'_id': '50018489', 'Avg grade': None}
# {'_id': '41182747', 'Avg grade': None}
# {'_id': '41115711', 'Avg grade': None}
# {'_id': '41703660', 'Avg grade': None}
# {'_id': '41720396', 'Avg grade': None}
# {'_id': '41331535', 'Avg grade': None}
# {'_id': '41236480', 'Avg grade': None}
# {'_id': '41684444', 'Avg grade': None}
# {'_id': '50007039', 'Avg grade': None}
# {'_id': '41226851', 'Avg grade': None}
# {'_id': '50010356', 'Avg grade': None}
# {'_id': '40703801', 'Avg grade': None}
# {'_id': '50014840', 'Avg grade': None}
# {'_id': '41554950', 'Avg grade': None}
# {'_id': '40580639', 'Avg grade': None}
# {'_id': '40623604', 'Avg grade': None}
# {'_id': '50011541', 'Avg grade': None}
# {'_id': '41423724', 'Avg grade': None}
# {'_id': '41592830', 'Avg grade': None}
# {'_id': '50002756', 'Avg grade': None}
# {'_id': '50017003', 'Avg grade': None}
# {'_id': '40363289', 'Avg grade': None}
# {'_id': '41247170', 'Avg grade': None}
# {'_id': '40662349', 'Avg grade': None}
# {'_id': '41606994', 'Avg grade': None}
# {'_id': '40396532', 'Avg grade': None}
# {'_id': '40402089', 'Avg grade': None}
# {'_id': '41389979', 'Avg grade': None}
# {'_id': '41569888', 'Avg grade': None}
# {'_id': '40385680', 'Avg grade': None}
# {'_id': '41261090', 'Avg grade': None}
# {'_id': '41618355', 'Avg grade': None}
# {'_id': '50003146', 'Avg grade': None}
# {'_id': '50005331', 'Avg grade': None}
# {'_id': '40391060', 'Avg grade': None}
# {'_id': '50010587', 'Avg grade': None}
# {'_id': '40395653', 'Avg grade': None}
# {'_id': '50010872', 'Avg grade': None}
# {'_id': '50013468', 'Avg grade': None}
# {'_id': '40946403', 'Avg grade': None}
# {'_id': '41696209', 'Avg grade': None}
# {'_id': '41703747', 'Avg grade': None}
# {'_id': '41385657', 'Avg grade': None}
# {'_id': '41663117', 'Avg grade': None}
# {'_id': '41218581', 'Avg grade': None}
# {'_id': '50012220', 'Avg grade': None}
# {'_id': '41561097', 'Avg grade': None}
# {'_id': '40371419', 'Avg grade': None}
# {'_id': '41685529', 'Avg grade': None}
# {'_id': '50006175', 'Avg grade': None}
# {'_id': '41410290', 'Avg grade': None}
# {'_id': '50008517', 'Avg grade': None}
# {'_id': '40885805', 'Avg grade': None}
# {'_id': '41341359', 'Avg grade': None}
# {'_id': '50012057', 'Avg grade': None}
# {'_id': '41590317', 'Avg grade': None}
# {'_id': '41709204', 'Avg grade': None}
# {'_id': '41328572', 'Avg grade': None}
# {'_id': '40997858', 'Avg grade': None}
# {'_id': '41721168', 'Avg grade': None}
# {'_id': '50000417', 'Avg grade': None}
# {'_id': '41607578', 'Avg grade': None}
# {'_id': '50008073', 'Avg grade': None}
# {'_id': '50017167', 'Avg grade': None}
# {'_id': '40370168', 'Avg grade': None}
# {'_id': '41410417', 'Avg grade': None}
# {'_id': '41644901', 'Avg grade': None}
# {'_id': '50003768', 'Avg grade': None}
# {'_id': '50015134', 'Avg grade': None}
# {'_id': '41547119', 'Avg grade': None}
# {'_id': '41672277', 'Avg grade': None}
# {'_id': '50014982', 'Avg grade': None}
# {'_id': '40867057', 'Avg grade': None}
# {'_id': '41556192', 'Avg grade': None}
# {'_id': '50018104', 'Avg grade': None}
# {'_id': '41514254', 'Avg grade': None}
# {'_id': '41563445', 'Avg grade': None}
# {'_id': '41004458', 'Avg grade': None}
# {'_id': '41507371', 'Avg grade': None}
# {'_id': '41686535', 'Avg grade': None}
# {'_id': '40401177', 'Avg grade': None}
# {'_id': '41030858', 'Avg grade': None}
# {'_id': '41495817', 'Avg grade': None}
# {'_id': '41108853', 'Avg grade': None}
# {'_id': '41547568', 'Avg grade': None}
# {'_id': '41435196', 'Avg grade': None}
# {'_id': '41180283', 'Avg grade': None}
# {'_id': '41290190', 'Avg grade': None}
# {'_id': '41249034', 'Avg grade': None}
# {'_id': '41399993', 'Avg grade': None}
# {'_id': '41619622', 'Avg grade': None}
# {'_id': '41649356', 'Avg grade': None}
# {'_id': '41681758', 'Avg grade': None}
# {'_id': '50003152', 'Avg grade': None}
# {'_id': '41254820', 'Avg grade': None}
# {'_id': '40377908', 'Avg grade': None}
# {'_id': '41718520', 'Avg grade': None}
# {'_id': '41711545', 'Avg grade': None}
# {'_id': '50009499', 'Avg grade': None}
# {'_id': '50016080', 'Avg grade': None}
# {'_id': '40600383', 'Avg grade': None}
# {'_id': '41390135', 'Avg grade': None}
# {'_id': '41659875', 'Avg grade': None}
# {'_id': '50015113', 'Avg grade': None}
# {'_id': '50012460', 'Avg grade': None}
# {'_id': '50000163', 'Avg grade': None}
# {'_id': '40401834', 'Avg grade': None}
# {'_id': '41117789', 'Avg grade': None}
# {'_id': '41421764', 'Avg grade': None}
# {'_id': '41329361', 'Avg grade': None}
# {'_id': '40367795', 'Avg grade': None}
# {'_id': '40401671', 'Avg grade': None}
# {'_id': '41371682', 'Avg grade': None}
# {'_id': '40400641', 'Avg grade': None}
# {'_id': '41622183', 'Avg grade': None}
# {'_id': '41632535', 'Avg grade': None}
# {'_id': '41692125', 'Avg grade': None}
# {'_id': '41393625', 'Avg grade': None}
# {'_id': '50001664', 'Avg grade': None}
# {'_id': '41125662', 'Avg grade': None}
# {'_id': '50003427', 'Avg grade': None}
# {'_id': '41581812', 'Avg grade': None}
# {'_id': '41582458', 'Avg grade': None}
# {'_id': '41694617', 'Avg grade': None}
# {'_id': '40941320', 'Avg grade': None}
# {'_id': '41514880', 'Avg grade': None}
# {'_id': '40404023', 'Avg grade': None}
# {'_id': '50014519', 'Avg grade': None}
# {'_id': '41105572', 'Avg grade': None}
# {'_id': '41718530', 'Avg grade': None}
# {'_id': '41365100', 'Avg grade': None}
# {'_id': '41570383', 'Avg grade': None}
# {'_id': '41707995', 'Avg grade': None}
# {'_id': '41695827', 'Avg grade': None}
# {'_id': '40390046', 'Avg grade': None}
# {'_id': '41713226', 'Avg grade': None}
# {'_id': '50002591', 'Avg grade': None}
# {'_id': '41266591', 'Avg grade': None}
# {'_id': '41515681', 'Avg grade': None}
# {'_id': '40404017', 'Avg grade': None}
# {'_id': '40534912', 'Avg grade': None}
# {'_id': '41597782', 'Avg grade': None}
# {'_id': '40398642', 'Avg grade': None}
# {'_id': '41616477', 'Avg grade': None}
# {'_id': '50001896', 'Avg grade': None}
# {'_id': '41480215', 'Avg grade': None}
# {'_id': '50004901', 'Avg grade': None}
# {'_id': '50014962', 'Avg grade': None}
# {'_id': '41009353', 'Avg grade': None}
# {'_id': '50017651', 'Avg grade': None}
# {'_id': '41639225', 'Avg grade': None}
# {'_id': '41695009', 'Avg grade': None}
# {'_id': '41242716', 'Avg grade': None}
# {'_id': '41683759', 'Avg grade': None}
# {'_id': '40400489', 'Avg grade': None}
# {'_id': '50000804', 'Avg grade': None}
# {'_id': '41679329', 'Avg grade': None}
# {'_id': '50003301', 'Avg grade': None}
# {'_id': '50006436', 'Avg grade': None}
# {'_id': '50017430', 'Avg grade': None}
# {'_id': '41551165', 'Avg grade': None}
# {'_id': '50008601', 'Avg grade': None}
# {'_id': '50018866', 'Avg grade': None}
# {'_id': '50002057', 'Avg grade': None}
# {'_id': '50006618', 'Avg grade': None}
# {'_id': '41445485', 'Avg grade': None}
# {'_id': '41488888', 'Avg grade': None}
# {'_id': '50017795', 'Avg grade': None}
# {'_id': '41301327', 'Avg grade': None}
# {'_id': '40869272', 'Avg grade': None}
# {'_id': '41463456', 'Avg grade': None}
# {'_id': '41717113', 'Avg grade': None}
# {'_id': '50015096', 'Avg grade': None}
# {'_id': '41661089', 'Avg grade': None}
# {'_id': '41375367', 'Avg grade': None}
# {'_id': '41474909', 'Avg grade': None}
# {'_id': '41579300', 'Avg grade': None}
# {'_id': '50007380', 'Avg grade': None}
# {'_id': '40700724', 'Avg grade': None}
# {'_id': '40611066', 'Avg grade': None}
# {'_id': '41515691', 'Avg grade': None}
# {'_id': '41579193', 'Avg grade': None}
# {'_id': '41117249', 'Avg grade': None}
# {'_id': '40987128', 'Avg grade': None}
# {'_id': '40580405', 'Avg grade': None}
# {'_id': '41647129', 'Avg grade': None}
# {'_id': '50005656', 'Avg grade': None}
# {'_id': '41212471', 'Avg grade': None}
# {'_id': '40367189', 'Avg grade': None}
# {'_id': '41497034', 'Avg grade': None}
# {'_id': '50018291', 'Avg grade': None}
# {'_id': '40594203', 'Avg grade': None}
# ...
# {'_id': '50011461', 'Avg grade': None}
# {'_id': '41202207', 'Avg grade': None}
# {'_id': '50012132', 'Avg grade': None}
# {'_id': '41449148', 'Avg grade': None}
# {'_id': '50018655', 'Avg grade': None}
# {'_id': '50010009', 'Avg grade': None}
# {'_id': '41567865', 'Avg grade': None}
# {'_id': '50018595', 'Avg grade': None}
# {'_id': '40705978', 'Avg grade': None}
# {'_id': '41654506', 'Avg grade': None}
# {'_id': '50012277', 'Avg grade': None}
# {'_id': '41708946', 'Avg grade': None}
# {'_id': '40368370', 'Avg grade': None}
# {'_id': '40939686', 'Avg grade': None}
# {'_id': '41120361', 'Avg grade': None}
# {'_id': '41233904', 'Avg grade': None}
# {'_id': '41105947', 'Avg grade': None}
# {'_id': '41432519', 'Avg grade': None}
# {'_id': '41058847', 'Avg grade': None}
# {'_id': '41455831', 'Avg grade': None}
# {'_id': '50001179', 'Avg grade': None}
# {'_id': '50003679', 'Avg grade': None}
# {'_id': '50000188', 'Avg grade': None}
# {'_id': '41336612', 'Avg grade': None}
# {'_id': '50008241', 'Avg grade': None}
# {'_id': '41251040', 'Avg grade': None}
# {'_id': '41594796', 'Avg grade': None}
# {'_id': '50001013', 'Avg grade': None}
# {'_id': '41539593', 'Avg grade': None}
# {'_id': '41672156', 'Avg grade': None}
# {'_id': '41703392', 'Avg grade': None}
# {'_id': '41689548', 'Avg grade': None}
# {'_id': '41640599', 'Avg grade': None}
# {'_id': '50006236', 'Avg grade': None}
# {'_id': '50007610', 'Avg grade': None}
# {'_id': '41335679', 'Avg grade': None}
# {'_id': '40582932', 'Avg grade': None}
# {'_id': '41127647', 'Avg grade': None}
# {'_id': '41501642', 'Avg grade': None}
# {'_id': '41579510', 'Avg grade': None}
# {'_id': '50001240', 'Avg grade': None}
# {'_id': '41024190', 'Avg grade': None}
# {'_id': '50016875', 'Avg grade': None}
# {'_id': '41607749', 'Avg grade': None}
# {'_id': '50009060', 'Avg grade': None}
# {'_id': '41512057', 'Avg grade': None}
# {'_id': '41645430', 'Avg grade': None}
# {'_id': '41286260', 'Avg grade': None}
# {'_id': '41473384', 'Avg grade': None}
# {'_id': '41565970', 'Avg grade': None}
# {'_id': '41276645', 'Avg grade': None}
# {'_id': '41374594', 'Avg grade': None}
# {'_id': '41406564', 'Avg grade': None}
# {'_id': '41434117', 'Avg grade': None}
# {'_id': '41363720', 'Avg grade': None}
# {'_id': '41538952', 'Avg grade': None}
# {'_id': '41555647', 'Avg grade': None}
# {'_id': '41605705', 'Avg grade': None}
# {'_id': '41687192', 'Avg grade': None}
# {'_id': '41707379', 'Avg grade': None}
# {'_id': '41710581', 'Avg grade': None}
# {'_id': '41263394', 'Avg grade': None}
# {'_id': '40996211', 'Avg grade': None}
# {'_id': '41043903', 'Avg grade': None}
# {'_id': '41373712', 'Avg grade': None}
# {'_id': '40529991', 'Avg grade': None}
# {'_id': '40692857', 'Avg grade': None}
# {'_id': '41495573', 'Avg grade': None}
# {'_id': '41632521', 'Avg grade': None}
# {'_id': '50003358', 'Avg grade': None}
# {'_id': '40969899', 'Avg grade': None}
# {'_id': '41152095', 'Avg grade': None}
# {'_id': '50000165', 'Avg grade': None}
# {'_id': '41713987', 'Avg grade': None}
# {'_id': '50007670', 'Avg grade': None}
# {'_id': '50008891', 'Avg grade': None}
# {'_id': '50010317', 'Avg grade': None}
# {'_id': '41463477', 'Avg grade': None}
# {'_id': '50012463', 'Avg grade': None}
# {'_id': '41244032', 'Avg grade': None}
# {'_id': '41658786', 'Avg grade': None}
# {'_id': '50013062', 'Avg grade': None}
# {'_id': '50003250', 'Avg grade': None}
# {'_id': '41020367', 'Avg grade': None}
# {'_id': '50012518', 'Avg grade': None}
# {'_id': '50014515', 'Avg grade': None}
# {'_id': '41541381', 'Avg grade': None}
# {'_id': '41608985', 'Avg grade': None}
# {'_id': '41528976', 'Avg grade': None}
# {'_id': '50001469', 'Avg grade': None}
# {'_id': '40862619', 'Avg grade': None}
# {'_id': '50018538', 'Avg grade': None}
# {'_id': '41289775', 'Avg grade': None}
# {'_id': '41696173', 'Avg grade': None}
# {'_id': '50002748', 'Avg grade': None}
# {'_id': '41487544', 'Avg grade': None}
# {'_id': '50005451', 'Avg grade': None}
# {'_id': '40729264', 'Avg grade': None}
# {'_id': '41488662', 'Avg grade': None}
# {'_id': '41636203', 'Avg grade': None}
# {'_id': '40761262', 'Avg grade': None}
# {'_id': '41417417', 'Avg grade': None}
# {'_id': '41562276', 'Avg grade': None}
# {'_id': '50000439', 'Avg grade': None}
# {'_id': '41549910', 'Avg grade': None}
# {'_id': '50000969', 'Avg grade': None}
# {'_id': '40839236', 'Avg grade': None}
# {'_id': '50012179', 'Avg grade': None}
# {'_id': '40388091', 'Avg grade': None}
# {'_id': '50013798', 'Avg grade': None}
# {'_id': '41601321', 'Avg grade': None}
# {'_id': '41210694', 'Avg grade': None}
# {'_id': '50005125', 'Avg grade': None}
# {'_id': '41698410', 'Avg grade': None}
# {'_id': '50008350', 'Avg grade': None}
# {'_id': '50015037', 'Avg grade': None}
# {'_id': '41506877', 'Avg grade': None}
# {'_id': '50002192', 'Avg grade': None}
# {'_id': '41314323', 'Avg grade': None}
# {'_id': '50015151', 'Avg grade': None}
# {'_id': '40398024', 'Avg grade': None}
# {'_id': '41541793', 'Avg grade': None}
# {'_id': '41469010', 'Avg grade': None}
# {'_id': '40538189', 'Avg grade': None}
# {'_id': '41402343', 'Avg grade': None}
# {'_id': '41639191', 'Avg grade': None}
# {'_id': '41384745', 'Avg grade': None}
# {'_id': '41546819', 'Avg grade': None}
# {'_id': '40400739', 'Avg grade': None}
# {'_id': '41615217', 'Avg grade': None}
# {'_id': '41624530', 'Avg grade': None}
# {'_id': '41007633', 'Avg grade': None}
# {'_id': '41391676', 'Avg grade': None}
# {'_id': '50009731', 'Avg grade': None}
# {'_id': '41264944', 'Avg grade': None}
# {'_id': '41122892', 'Avg grade': None}
# {'_id': '41640535', 'Avg grade': None}
# {'_id': '50017684', 'Avg grade': None}
# {'_id': '50002319', 'Avg grade': None}
# {'_id': '40918579', 'Avg grade': None}
# {'_id': '41271176', 'Avg grade': None}
# {'_id': '41549334', 'Avg grade': None}
# {'_id': '41221518', 'Avg grade': None}
# {'_id': '41536698', 'Avg grade': None}
# {'_id': '41638429', 'Avg grade': None}
# {'_id': '41266955', 'Avg grade': None}
# {'_id': '41661617', 'Avg grade': None}
# {'_id': '41580082', 'Avg grade': None}
# {'_id': '41107527', 'Avg grade': None}
# {'_id': '41236577', 'Avg grade': None}
# {'_id': '50009048', 'Avg grade': None}
# {'_id': '40750062', 'Avg grade': None}
# {'_id': '41573992', 'Avg grade': None}
# {'_id': '50008767', 'Avg grade': None}
# {'_id': '41438516', 'Avg grade': None}
# {'_id': '50016500', 'Avg grade': None}
# {'_id': '41220121', 'Avg grade': None}
# {'_id': '41564417', 'Avg grade': None}
# {'_id': '50017080', 'Avg grade': None}
# {'_id': '40968428', 'Avg grade': None}
# {'_id': '41316656', 'Avg grade': None}
# {'_id': '50003658', 'Avg grade': None}
# {'_id': '41019613', 'Avg grade': None}
# {'_id': '40734447', 'Avg grade': None}
# {'_id': '41112524', 'Avg grade': None}
# {'_id': '41315492', 'Avg grade': None}
# {'_id': '41527515', 'Avg grade': None}
# {'_id': '41592302', 'Avg grade': None}
# {'_id': '50000342', 'Avg grade': None}
# {'_id': '50008029', 'Avg grade': None}
# {'_id': '50011700', 'Avg grade': None}
# {'_id': '50014761', 'Avg grade': None}
# {'_id': '50016678', 'Avg grade': None}
# {'_id': '40885485', 'Avg grade': None}
# {'_id': '41241757', 'Avg grade': None}
# {'_id': '41491144', 'Avg grade': None}
# {'_id': '41319433', 'Avg grade': None}
# {'_id': '50008183', 'Avg grade': None}
# {'_id': '41076967', 'Avg grade': None}
# {'_id': '41033173', 'Avg grade': None}
# {'_id': '50016672', 'Avg grade': None}
# {'_id': '50018699', 'Avg grade': None}
# {'_id': '50001050', 'Avg grade': None}
# {'_id': '40369521', 'Avg grade': None}
# {'_id': '40994007', 'Avg grade': None}
# {'_id': '40402742', 'Avg grade': None}
# {'_id': '40936053', 'Avg grade': None}
# {'_id': '41056200', 'Avg grade': None}
# {'_id': '41073604', 'Avg grade': None}
# {'_id': '41362451', 'Avg grade': None}
# {'_id': '41555588', 'Avg grade': None}
# {'_id': '41688120', 'Avg grade': None}
# {'_id': '50012432', 'Avg grade': None}
# {'_id': '41142418', 'Avg grade': None}
# {'_id': '41570191', 'Avg grade': None}
# {'_id': '40927832', 'Avg grade': None}
# {'_id': '50014351', 'Avg grade': None}
# {'_id': '41508685', 'Avg grade': None}
# {'_id': '41653951', 'Avg grade': None}
# {'_id': '40395110', 'Avg grade': None}
# {'_id': '41418818', 'Avg grade': None}
# {'_id': '40899816', 'Avg grade': None}
# {'_id': '40829831', 'Avg grade': None}
# {'_id': '41634744', 'Avg grade': None}
# {'_id': '41641818', 'Avg grade': None}
# {'_id': '50000047', 'Avg grade': None}
# {'_id': '50010058', 'Avg grade': None}
# {'_id': '41388798', 'Avg grade': None}
# {'_id': '41721159', 'Avg grade': None}
# {'_id': '40365644', 'Avg grade': None}
# {'_id': '41652049', 'Avg grade': None}
# {'_id': '41554863', 'Avg grade': None}
# {'_id': '41303343', 'Avg grade': None}
# {'_id': '41190814', 'Avg grade': None}
# {'_id': '41695291', 'Avg grade': None}
# {'_id': '41374876', 'Avg grade': None}
# {'_id': '40393679', 'Avg grade': None}
# {'_id': '40362344', 'Avg grade': None}
# {'_id': '41091988', 'Avg grade': None}
# {'_id': '41649778', 'Avg grade': None}
# {'_id': '40363945', 'Avg grade': None}
# {'_id': '41276498', 'Avg grade': None}
# {'_id': '41608264', 'Avg grade': None}
# {'_id': '40662091', 'Avg grade': None}
# {'_id': '41264160', 'Avg grade': None}
# {'_id': '41691378', 'Avg grade': None}
# {'_id': '41470250', 'Avg grade': None}
# {'_id': '41596557', 'Avg grade': None}
# {'_id': '41388348', 'Avg grade': None}
# {'_id': '50002055', 'Avg grade': None}
# {'_id': '50006147', 'Avg grade': None}
# {'_id': '40717261', 'Avg grade': None}
# {'_id': '41510637', 'Avg grade': None}
# {'_id': '40401217', 'Avg grade': None}
# {'_id': '41638069', 'Avg grade': None}
# {'_id': '50009379', 'Avg grade': None}
# {'_id': '50001063', 'Avg grade': None}
# {'_id': '41614537', 'Avg grade': None}
# {'_id': '40684999', 'Avg grade': None}
# {'_id': '40808305', 'Avg grade': None}
# {'_id': '41302113', 'Avg grade': None}
# {'_id': '40949724', 'Avg grade': None}
# {'_id': '40398852', 'Avg grade': None}
# {'_id': '41075977', 'Avg grade': None}
# {'_id': '41454425', 'Avg grade': None}
# {'_id': '50001068', 'Avg grade': None}
# {'_id': '50008364', 'Avg grade': None}
# {'_id': '50008783', 'Avg grade': None}
# {'_id': '41098211', 'Avg grade': None}
# {'_id': '41505347', 'Avg grade': None}
# {'_id': '50009816', 'Avg grade': None}
# {'_id': '50011142', 'Avg grade': None}
# {'_id': '50012059', 'Avg grade': None}
# {'_id': '41185899', 'Avg grade': None}
# {'_id': '50003416', 'Avg grade': None}
# {'_id': '50009843', 'Avg grade': None}
# {'_id': '41450924', 'Avg grade': None}
# {'_id': '41595293', 'Avg grade': None}
# {'_id': '41107259', 'Avg grade': None}
# {'_id': '50001556', 'Avg grade': None}
# {'_id': '50012055', 'Avg grade': None}
# {'_id': '41057360', 'Avg grade': None}
# {'_id': '41645620', 'Avg grade': None}
# {'_id': '50009481', 'Avg grade': None}
# {'_id': '50016018', 'Avg grade': None}
# {'_id': '41553375', 'Avg grade': None}
# {'_id': '50004330', 'Avg grade': None}
# {'_id': '40544529', 'Avg grade': None}
# {'_id': '41310363', 'Avg grade': None}
# {'_id': '41341181', 'Avg grade': None}
# {'_id': '40401691', 'Avg grade': None}
# {'_id': '40919024', 'Avg grade': None}
# {'_id': '41640776', 'Avg grade': None}
# {'_id': '41693861', 'Avg grade': None}
# {'_id': '50002371', 'Avg grade': None}
# {'_id': '50004797', 'Avg grade': None}
# {'_id': '40367164', 'Avg grade': None}
# {'_id': '41680117', 'Avg grade': None}
# {'_id': '41470093', 'Avg grade': None}
# {'_id': '40401155', 'Avg grade': None}
# {'_id': '41035201', 'Avg grade': None}
# {'_id': '41565705', 'Avg grade': None}
# {'_id': '40381811', 'Avg grade': None}
# {'_id': '40960698', 'Avg grade': None}
# {'_id': '41565551', 'Avg grade': None}
# {'_id': '41426303', 'Avg grade': None}
# {'_id': '50002120', 'Avg grade': None}
# {'_id': '50003614', 'Avg grade': None}
# {'_id': '50011554', 'Avg grade': None}
# {'_id': '50012852', 'Avg grade': None}
# {'_id': '40928079', 'Avg grade': None}
# {'_id': '41413230', 'Avg grade': None}
# {'_id': '41680991', 'Avg grade': None}
# {'_id': '41720892', 'Avg grade': None}
# {'_id': '41033350', 'Avg grade': None}
# {'_id': '41374355', 'Avg grade': None}
# {'_id': '40824688', 'Avg grade': None}
# {'_id': '41233430', 'Avg grade': None}
# {'_id': '41615281', 'Avg grade': None}
# {'_id': '41678685', 'Avg grade': None}
# {'_id': '41720397', 'Avg grade': None}
# {'_id': '50002970', 'Avg grade': None}
# {'_id': '50014008', 'Avg grade': None}
# {'_id': '41577920', 'Avg grade': None}
# {'_id': '50015094', 'Avg grade': None}
# {'_id': '50015326', 'Avg grade': None}
# {'_id': '41431231', 'Avg grade': None}
# {'_id': '50001908', 'Avg grade': None}
# {'_id': '41185133', 'Avg grade': None}
# {'_id': '50009620', 'Avg grade': None}
# {'_id': '41495455', 'Avg grade': None}
# {'_id': '41628808', 'Avg grade': None}
# {'_id': '41711510', 'Avg grade': None}
# {'_id': '50000966', 'Avg grade': None}
# {'_id': '50011528', 'Avg grade': None}
# {'_id': '41291275', 'Avg grade': None}
# {'_id': '41632888', 'Avg grade': None}
# {'_id': '41703793', 'Avg grade': None}
# {'_id': '50010429', 'Avg grade': None}
# {'_id': '50015327', 'Avg grade': None}
# {'_id': '50002486', 'Avg grade': None}
# {'_id': '41594425', 'Avg grade': None}
# {'_id': '41090127', 'Avg grade': None}
# {'_id': '41638716', 'Avg grade': None}
# {'_id': '41428124', 'Avg grade': None}
# {'_id': '41621868', 'Avg grade': None}
# {'_id': '50004305', 'Avg grade': None}
# {'_id': '41560840', 'Avg grade': None}
# {'_id': '41161594', 'Avg grade': None}
# {'_id': '41224938', 'Avg grade': None}
# {'_id': '41516062', 'Avg grade': None}
# {'_id': '41629694', 'Avg grade': None}
# {'_id': '50010496', 'Avg grade': None}
# {'_id': '50012550', 'Avg grade': None}
# {'_id': '41635392', 'Avg grade': None}
# {'_id': '50018953', 'Avg grade': None}
# {'_id': '41308135', 'Avg grade': None}
# {'_id': '41439359', 'Avg grade': None}
# {'_id': '41565921', 'Avg grade': None}
# {'_id': '40396267', 'Avg grade': None}
# {'_id': '40655946', 'Avg grade': None}
# {'_id': '41388613', 'Avg grade': None}
# {'_id': '41610065', 'Avg grade': None}
# {'_id': '41717443', 'Avg grade': None}
# {'_id': '50009326', 'Avg grade': None}
# {'_id': '50011230', 'Avg grade': None}
# {'_id': '41139255', 'Avg grade': None}
# {'_id': '50014424', 'Avg grade': None}
# {'_id': '41613392', 'Avg grade': None}
# {'_id': '50012352', 'Avg grade': None}
# {'_id': '40861140', 'Avg grade': None}
# {'_id': '41420291', 'Avg grade': None}
# {'_id': '40547904', 'Avg grade': None}
# {'_id': '41699904', 'Avg grade': None}
# {'_id': '41701176', 'Avg grade': None}
# {'_id': '41413875', 'Avg grade': None}
# {'_id': '41719137', 'Avg grade': None}
# {'_id': '41706229', 'Avg grade': None}
# {'_id': '50002763', 'Avg grade': None}
# {'_id': '50004608', 'Avg grade': None}
# {'_id': '50007315', 'Avg grade': None}
# {'_id': '41464542', 'Avg grade': None}
# {'_id': '50012093', 'Avg grade': None}
# {'_id': '50005663', 'Avg grade': None}
# {'_id': '41030615', 'Avg grade': None}
# {'_id': '41629043', 'Avg grade': None}
# {'_id': '41612649', 'Avg grade': None}
# {'_id': '41700785', 'Avg grade': None}
# {'_id': '40375839', 'Avg grade': None}
# {'_id': '41678996', 'Avg grade': None}
# {'_id': '50004681', 'Avg grade': None}
# {'_id': '41286006', 'Avg grade': None}
# {'_id': '40984272', 'Avg grade': None}
# {'_id': '40799188', 'Avg grade': None}
# {'_id': '41467866', 'Avg grade': None}
# {'_id': '41689595', 'Avg grade': None}
# {'_id': '50006351', 'Avg grade': None}
# {'_id': '41653536', 'Avg grade': None}
# {'_id': '50010540', 'Avg grade': None}
# {'_id': '50010074', 'Avg grade': None}
# {'_id': '41227603', 'Avg grade': None}
# {'_id': '41344828', 'Avg grade': None}
# {'_id': '41475992', 'Avg grade': None}
# {'_id': '41400593', 'Avg grade': None}
# {'_id': '40424633', 'Avg grade': None}
# {'_id': '40695260', 'Avg grade': None}
# {'_id': '41548180', 'Avg grade': None}
# {'_id': '41433405', 'Avg grade': None}
# {'_id': '41000357', 'Avg grade': None}
# {'_id': '41667036', 'Avg grade': None}
# {'_id': '41435053', 'Avg grade': None}
# {'_id': '50008060', 'Avg grade': None}
# {'_id': '40927513', 'Avg grade': None}
# {'_id': '40958613', 'Avg grade': None}
# {'_id': '41251789', 'Avg grade': None}
# {'_id': '41484499', 'Avg grade': None}
# {'_id': '40756209', 'Avg grade': None}
# {'_id': '41605151', 'Avg grade': None}
# {'_id': '50000205', 'Avg grade': None}
# {'_id': '50004624', 'Avg grade': None}
# {'_id': '41428706', 'Avg grade': None}
# {'_id': '41455169', 'Avg grade': None}
# {'_id': '41672058', 'Avg grade': None}
# {'_id': '40659758', 'Avg grade': None}
# {'_id': '41603176', 'Avg grade': None}
# {'_id': '50000991', 'Avg grade': None}
# {'_id': '50011099', 'Avg grade': None}
# {'_id': '50012051', 'Avg grade': None}
# {'_id': '41010772', 'Avg grade': None}
# {'_id': '41644127', 'Avg grade': None}

# %%
#do it again, but now add unwind. See the result table....What does unwind do, what changes and why does it 
#work now?

result = restaurants.aggregate(
  [
     {"$unwind": "$grades"},
     {"$match": {}}, 
     {"$group": {"_id": "$restaurant_id", "Avg grade": {"$avg": "$grades.score" }}}
  ]
)

# %%
#redo query but now also sort the returned in ascending or descending order. 
#We could simply add another line with the sort parameter specifying which field to sort by. 
#1 (ascending) or -1 (descending).

#do it again, but now add unwind. See the result table....What does unwind do, what changes and why does it 
#work now?

result = restaurants.aggregate(
  [
     {"$unwind": "$grades"},
     {"$match": {}}, 
     {"$group": {"_id": "$restaurant_id", "Avg grade": {"$avg": "$grades.score" }}},
     {"$sort": {"Avg grade": -1}}
  ]
)

# %%
#print result, see if ot is sorted correctly:
for item in result:
    print(item)
# Out:
# {'_id': '50015959', 'Avg grade': 75.0}
# {'_id': '50017374', 'Avg grade': 73.0}
# {'_id': '50018457', 'Avg grade': 69.0}
# {'_id': '50015245', 'Avg grade': 69.0}
# {'_id': '41703965', 'Avg grade': 65.0}
# {'_id': '50017252', 'Avg grade': 61.0}
# {'_id': '50011285', 'Avg grade': 61.0}
# {'_id': '50013507', 'Avg grade': 60.0}
# {'_id': '50011359', 'Avg grade': 60.0}
# {'_id': '50018376', 'Avg grade': 58.0}
# {'_id': '50016721', 'Avg grade': 56.0}
# {'_id': '50015482', 'Avg grade': 56.0}
# {'_id': '50016506', 'Avg grade': 56.0}
# {'_id': '50018079', 'Avg grade': 56.0}
# {'_id': '50018468', 'Avg grade': 56.0}
# {'_id': '50016149', 'Avg grade': 54.0}
# {'_id': '50000607', 'Avg grade': 53.0}
# {'_id': '41720129', 'Avg grade': 53.0}
# {'_id': '50018202', 'Avg grade': 53.0}
# {'_id': '50016844', 'Avg grade': 52.0}
# {'_id': '50018031', 'Avg grade': 52.0}
# {'_id': '50010667', 'Avg grade': 52.0}
# {'_id': '50014838', 'Avg grade': 49.0}
# {'_id': '50017111', 'Avg grade': 48.0}
# {'_id': '50012011', 'Avg grade': 47.0}
# {'_id': '50017866', 'Avg grade': 47.0}
# {'_id': '50018535', 'Avg grade': 47.0}
# {'_id': '50016483', 'Avg grade': 46.0}
# {'_id': '50002843', 'Avg grade': 46.0}
# {'_id': '50014192', 'Avg grade': 46.0}
# {'_id': '50015243', 'Avg grade': 44.0}
# {'_id': '50010362', 'Avg grade': 44.0}
# {'_id': '41698293', 'Avg grade': 44.0}
# {'_id': '50017185', 'Avg grade': 44.0}
# {'_id': '50018480', 'Avg grade': 43.0}
# {'_id': '50014704', 'Avg grade': 43.0}
# {'_id': '50010507', 'Avg grade': 43.0}
# {'_id': '50017434', 'Avg grade': 43.0}
# {'_id': '50001672', 'Avg grade': 43.0}
# {'_id': '50009015', 'Avg grade': 43.0}
# {'_id': '50000933', 'Avg grade': 42.0}
# {'_id': '50018294', 'Avg grade': 42.0}
# {'_id': '50017271', 'Avg grade': 42.0}
# {'_id': '50017981', 'Avg grade': 41.0}
# {'_id': '50017390', 'Avg grade': 41.0}
# {'_id': '50018003', 'Avg grade': 41.0}
# {'_id': '50011140', 'Avg grade': 41.0}
# {'_id': '41706169', 'Avg grade': 40.0}
# {'_id': '50015043', 'Avg grade': 40.0}
# {'_id': '50014874', 'Avg grade': 40.0}
# {'_id': '50017154', 'Avg grade': 40.0}
# {'_id': '50005299', 'Avg grade': 40.0}
# {'_id': '50016984', 'Avg grade': 40.0}
# {'_id': '50016357', 'Avg grade': 40.0}
# {'_id': '50014170', 'Avg grade': 40.0}
# {'_id': '50008355', 'Avg grade': 40.0}
# {'_id': '41470133', 'Avg grade': 39.666666666666664}
# {'_id': '50017895', 'Avg grade': 39.0}
# {'_id': '41462169', 'Avg grade': 39.0}
# {'_id': '50017182', 'Avg grade': 39.0}
# {'_id': '40393488', 'Avg grade': 38.6}
# {'_id': '40946690', 'Avg grade': 38.5}
# {'_id': '50010811', 'Avg grade': 38.0}
# {'_id': '50016046', 'Avg grade': 38.0}
# {'_id': '50014723', 'Avg grade': 38.0}
# {'_id': '50011338', 'Avg grade': 38.0}
# {'_id': '50010023', 'Avg grade': 38.0}
# {'_id': '50017481', 'Avg grade': 38.0}
# {'_id': '50002558', 'Avg grade': 38.0}
# {'_id': '50016773', 'Avg grade': 38.0}
# {'_id': '41267350', 'Avg grade': 37.4}
# {'_id': '50000604', 'Avg grade': 37.0}
# {'_id': '50006737', 'Avg grade': 37.0}
# {'_id': '50017732', 'Avg grade': 37.0}
# {'_id': '50011858', 'Avg grade': 37.0}
# {'_id': '50015473', 'Avg grade': 37.0}
# {'_id': '50014385', 'Avg grade': 37.0}
# {'_id': '50015564', 'Avg grade': 37.0}
# {'_id': '50009764', 'Avg grade': 36.5}
# {'_id': '50004305', 'Avg grade': 36.5}
# {'_id': '41602559', 'Avg grade': 36.285714285714285}
# {'_id': '50015155', 'Avg grade': 36.0}
# {'_id': '40756344', 'Avg grade': 36.0}
# {'_id': '50016423', 'Avg grade': 36.0}
# {'_id': '50015520', 'Avg grade': 36.0}
# {'_id': '50016152', 'Avg grade': 36.0}
# {'_id': '50017821', 'Avg grade': 36.0}
# {'_id': '50017013', 'Avg grade': 35.5}
# {'_id': '50006132', 'Avg grade': 35.5}
# {'_id': '50004065', 'Avg grade': 35.5}
# {'_id': '50017071', 'Avg grade': 35.0}
# {'_id': '50002472', 'Avg grade': 35.0}
# {'_id': '50017148', 'Avg grade': 35.0}
# {'_id': '50016010', 'Avg grade': 35.0}
# {'_id': '50017443', 'Avg grade': 35.0}
# {'_id': '50014668', 'Avg grade': 35.0}
# {'_id': '50014571', 'Avg grade': 35.0}
# {'_id': '50014405', 'Avg grade': 35.0}
# {'_id': '50014244', 'Avg grade': 35.0}
# {'_id': '50017814', 'Avg grade': 35.0}
# {'_id': '50015255', 'Avg grade': 35.0}
# {'_id': '41550400', 'Avg grade': 34.8}
# {'_id': '41363541', 'Avg grade': 34.75}
# {'_id': '50012832', 'Avg grade': 34.0}
# {'_id': '50015343', 'Avg grade': 34.0}
# {'_id': '50016637', 'Avg grade': 34.0}
# {'_id': '50009844', 'Avg grade': 34.0}
# {'_id': '50007005', 'Avg grade': 34.0}
# {'_id': '50006235', 'Avg grade': 34.0}
# {'_id': '50011499', 'Avg grade': 34.0}
# {'_id': '50003738', 'Avg grade': 34.0}
# {'_id': '50006215', 'Avg grade': 34.0}
# {'_id': '50017136', 'Avg grade': 34.0}
# {'_id': '50007645', 'Avg grade': 34.0}
# {'_id': '41683783', 'Avg grade': 34.0}
# {'_id': '50013567', 'Avg grade': 34.0}
# {'_id': '50018704', 'Avg grade': 34.0}
# {'_id': '50015846', 'Avg grade': 34.0}
# {'_id': '50011594', 'Avg grade': 34.0}
# {'_id': '40372466', 'Avg grade': 33.666666666666664}
# {'_id': '50002060', 'Avg grade': 33.5}
# {'_id': '50007216', 'Avg grade': 33.5}
# {'_id': '50002734', 'Avg grade': 33.5}
# {'_id': '50017477', 'Avg grade': 33.0}
# {'_id': '50017404', 'Avg grade': 33.0}
# {'_id': '50018314', 'Avg grade': 33.0}
# {'_id': '50009033', 'Avg grade': 33.0}
# {'_id': '50017351', 'Avg grade': 33.0}
# {'_id': '50013833', 'Avg grade': 33.0}
# {'_id': '50015802', 'Avg grade': 33.0}
# {'_id': '50017871', 'Avg grade': 33.0}
# {'_id': '50017035', 'Avg grade': 33.0}
# {'_id': '40979431', 'Avg grade': 33.0}
# {'_id': '50006344', 'Avg grade': 33.0}
# {'_id': '50017092', 'Avg grade': 33.0}
# {'_id': '41389275', 'Avg grade': 32.75}
# {'_id': '41712791', 'Avg grade': 32.666666666666664}
# {'_id': '50001020', 'Avg grade': 32.666666666666664}
# {'_id': '40387237', 'Avg grade': 32.6}
# {'_id': '50005404', 'Avg grade': 32.5}
# {'_id': '50009226', 'Avg grade': 32.5}
# {'_id': '41164678', 'Avg grade': 32.42857142857143}
# {'_id': '40366157', 'Avg grade': 32.142857142857146}
# {'_id': '50001368', 'Avg grade': 32.0}
# {'_id': '41705332', 'Avg grade': 32.0}
# {'_id': '41488795', 'Avg grade': 32.0}
# {'_id': '50001865', 'Avg grade': 32.0}
# {'_id': '50014251', 'Avg grade': 32.0}
# {'_id': '50013450', 'Avg grade': 32.0}
# {'_id': '50015303', 'Avg grade': 32.0}
# {'_id': '50017310', 'Avg grade': 32.0}
# {'_id': '50015855', 'Avg grade': 32.0}
# {'_id': '50014697', 'Avg grade': 32.0}
# {'_id': '50016167', 'Avg grade': 32.0}
# {'_id': '50017269', 'Avg grade': 32.0}
# {'_id': '50015737', 'Avg grade': 32.0}
# {'_id': '50000040', 'Avg grade': 31.75}
# {'_id': '50007007', 'Avg grade': 31.5}
# {'_id': '41489694', 'Avg grade': 31.333333333333332}
# {'_id': '50012471', 'Avg grade': 31.0}
# {'_id': '50015627', 'Avg grade': 31.0}
# {'_id': '50016851', 'Avg grade': 31.0}
# {'_id': '50014465', 'Avg grade': 31.0}
# {'_id': '50015572', 'Avg grade': 31.0}
# {'_id': '50006705', 'Avg grade': 31.0}
# {'_id': '50017113', 'Avg grade': 31.0}
# {'_id': '50016319', 'Avg grade': 31.0}
# {'_id': '50018736', 'Avg grade': 31.0}
# {'_id': '50013662', 'Avg grade': 31.0}
# {'_id': '41004546', 'Avg grade': 31.0}
# {'_id': '50012532', 'Avg grade': 31.0}
# {'_id': '50017120', 'Avg grade': 31.0}
# {'_id': '41648639', 'Avg grade': 30.8}
# {'_id': '41694991', 'Avg grade': 30.8}
# {'_id': '40825993', 'Avg grade': 30.8}
# {'_id': '40374268', 'Avg grade': 30.8}
# {'_id': '41459809', 'Avg grade': 30.714285714285715}
# {'_id': '50001880', 'Avg grade': 30.666666666666668}
# {'_id': '40959046', 'Avg grade': 30.6}
# {'_id': '40624470', 'Avg grade': 30.6}
# {'_id': '41410058', 'Avg grade': 30.6}
# {'_id': '41712283', 'Avg grade': 30.5}
# {'_id': '41474882', 'Avg grade': 30.4}
# {'_id': '41633319', 'Avg grade': 30.333333333333332}
# {'_id': '50002765', 'Avg grade': 30.333333333333332}
# {'_id': '41660581', 'Avg grade': 30.285714285714285}
# {'_id': '41679611', 'Avg grade': 30.25}
# {'_id': '50018111', 'Avg grade': 30.0}
# {'_id': '50015035', 'Avg grade': 30.0}
# {'_id': '50004117', 'Avg grade': 30.0}
# {'_id': '50018057', 'Avg grade': 30.0}
# {'_id': '50017560', 'Avg grade': 30.0}
# {'_id': '50017822', 'Avg grade': 30.0}
# {'_id': '40601738', 'Avg grade': 30.0}
# {'_id': '50011225', 'Avg grade': 30.0}
# {'_id': '50008981', 'Avg grade': 30.0}
# {'_id': '41601132', 'Avg grade': 30.0}
# {'_id': '50011828', 'Avg grade': 30.0}
# {'_id': '50004076', 'Avg grade': 30.0}
# {'_id': '41325464', 'Avg grade': 30.0}
# {'_id': '50017651', 'Avg grade': 30.0}
# {'_id': '50002338', 'Avg grade': 30.0}
# {'_id': '41717279', 'Avg grade': 30.0}
# {'_id': '50017941', 'Avg grade': 30.0}
# {'_id': '50017167', 'Avg grade': 30.0}
# {'_id': '50011592', 'Avg grade': 30.0}
# {'_id': '41667132', 'Avg grade': 30.0}
# {'_id': '50006092', 'Avg grade': 30.0}
# {'_id': '50017674', 'Avg grade': 30.0}
# {'_id': '41698470', 'Avg grade': 30.0}
# {'_id': '40785901', 'Avg grade': 29.833333333333332}
# {'_id': '41503136', 'Avg grade': 29.833333333333332}
# {'_id': '41608854', 'Avg grade': 29.8}
# {'_id': '40821641', 'Avg grade': 29.8}
# {'_id': '41418489', 'Avg grade': 29.75}
# {'_id': '50002897', 'Avg grade': 29.666666666666668}
# {'_id': '41609237', 'Avg grade': 29.5}
# {'_id': '50001949', 'Avg grade': 29.5}
# {'_id': '41694159', 'Avg grade': 29.5}
# {'_id': '50003708', 'Avg grade': 29.5}
# {'_id': '41721069', 'Avg grade': 29.333333333333332}
# {'_id': '41683812', 'Avg grade': 29.333333333333332}
# {'_id': '41434866', 'Avg grade': 29.285714285714285}
# {'_id': '41233430', 'Avg grade': 29.142857142857142}
# {'_id': '50002782', 'Avg grade': 29.0}
# {'_id': '50003474', 'Avg grade': 29.0}
# {'_id': '41682994', 'Avg grade': 29.0}
# {'_id': '50002355', 'Avg grade': 29.0}
# {'_id': '50016526', 'Avg grade': 29.0}
# {'_id': '50017773', 'Avg grade': 29.0}
# {'_id': '50001330', 'Avg grade': 29.0}
# {'_id': '50016753', 'Avg grade': 29.0}
# {'_id': '50018547', 'Avg grade': 29.0}
# {'_id': '50002249', 'Avg grade': 29.0}
# {'_id': '50014935', 'Avg grade': 29.0}
# {'_id': '50014494', 'Avg grade': 29.0}
# {'_id': '50017582', 'Avg grade': 29.0}
# {'_id': '50017074', 'Avg grade': 29.0}
# {'_id': '50000741', 'Avg grade': 29.0}
# {'_id': '41711186', 'Avg grade': 29.0}
# {'_id': '40987023', 'Avg grade': 29.0}
# {'_id': '50011814', 'Avg grade': 29.0}
# {'_id': '41212249', 'Avg grade': 28.75}
# {'_id': '41660217', 'Avg grade': 28.666666666666668}
# {'_id': '41038679', 'Avg grade': 28.666666666666668}
# {'_id': '41630826', 'Avg grade': 28.666666666666668}
# {'_id': '41495562', 'Avg grade': 28.5}
# {'_id': '50006963', 'Avg grade': 28.5}
# {'_id': '41383892', 'Avg grade': 28.5}
# {'_id': '41338985', 'Avg grade': 28.5}
# {'_id': '50004319', 'Avg grade': 28.5}
# {'_id': '50001204', 'Avg grade': 28.5}
# {'_id': '50004457', 'Avg grade': 28.5}
# {'_id': '40704853', 'Avg grade': 28.428571428571427}
# {'_id': '41654083', 'Avg grade': 28.4}
# {'_id': '41612015', 'Avg grade': 28.25}
# {'_id': '41699488', 'Avg grade': 28.25}
# {'_id': '41317790', 'Avg grade': 28.166666666666668}
# {'_id': '50015183', 'Avg grade': 28.0}
# {'_id': '50018204', 'Avg grade': 28.0}
# {'_id': '41638458', 'Avg grade': 28.0}
# {'_id': '50017297', 'Avg grade': 28.0}
# {'_id': '50018028', 'Avg grade': 28.0}
# {'_id': '41547596', 'Avg grade': 28.0}
# {'_id': '50017407', 'Avg grade': 28.0}
# {'_id': '50014456', 'Avg grade': 28.0}
# {'_id': '50016995', 'Avg grade': 28.0}
# {'_id': '50011324', 'Avg grade': 28.0}
# {'_id': '50016973', 'Avg grade': 28.0}
# {'_id': '41083343', 'Avg grade': 28.0}
# {'_id': '50017985', 'Avg grade': 28.0}
# {'_id': '50001921', 'Avg grade': 28.0}
# {'_id': '41675700', 'Avg grade': 28.0}
# {'_id': '40678067', 'Avg grade': 28.0}
# {'_id': '50016455', 'Avg grade': 28.0}
# {'_id': '50017762', 'Avg grade': 28.0}
# {'_id': '50016328', 'Avg grade': 28.0}
# {'_id': '50012579', 'Avg grade': 28.0}
# {'_id': '40700664', 'Avg grade': 27.833333333333332}
# {'_id': '41498674', 'Avg grade': 27.833333333333332}
# {'_id': '41569277', 'Avg grade': 27.833333333333332}
# {'_id': '40690019', 'Avg grade': 27.833333333333332}
# {'_id': '40401316', 'Avg grade': 27.833333333333332}
# {'_id': '41472847', 'Avg grade': 27.8}
# {'_id': '41614664', 'Avg grade': 27.8}
# {'_id': '41469010', 'Avg grade': 27.714285714285715}
# {'_id': '41629392', 'Avg grade': 27.666666666666668}
# {'_id': '41616749', 'Avg grade': 27.6}
# {'_id': '40358429', 'Avg grade': 27.6}
# {'_id': '41122196', 'Avg grade': 27.571428571428573}
# {'_id': '41190515', 'Avg grade': 27.5}
# {'_id': '50004368', 'Avg grade': 27.5}
# {'_id': '41158299', 'Avg grade': 27.5}
# {'_id': '50001036', 'Avg grade': 27.5}
# {'_id': '41376986', 'Avg grade': 27.5}
# {'_id': '50007308', 'Avg grade': 27.5}
# {'_id': '41529712', 'Avg grade': 27.5}
# {'_id': '41155285', 'Avg grade': 27.5}
# {'_id': '50008244', 'Avg grade': 27.5}
# {'_id': '41684996', 'Avg grade': 27.4}
# {'_id': '41267063', 'Avg grade': 27.333333333333332}
# {'_id': '41336841', 'Avg grade': 27.2}
# {'_id': '41510846', 'Avg grade': 27.166666666666668}
# {'_id': '41574642', 'Avg grade': 27.166666666666668}
# {'_id': '41708289', 'Avg grade': 27.0}
# {'_id': '50007431', 'Avg grade': 27.0}
# {'_id': '50011328', 'Avg grade': 27.0}
# {'_id': '50004719', 'Avg grade': 27.0}
# {'_id': '50015433', 'Avg grade': 27.0}
# {'_id': '50014990', 'Avg grade': 27.0}
# {'_id': '50018098', 'Avg grade': 27.0}
# {'_id': '50001021', 'Avg grade': 27.0}
# {'_id': '50014974', 'Avg grade': 27.0}
# {'_id': '50012113', 'Avg grade': 27.0}
# {'_id': '40725591', 'Avg grade': 27.0}
# {'_id': '50015517', 'Avg grade': 27.0}
# {'_id': '50011569', 'Avg grade': 27.0}
# {'_id': '50016658', 'Avg grade': 27.0}
# {'_id': '50010025', 'Avg grade': 27.0}
# {'_id': '50009999', 'Avg grade': 27.0}
# {'_id': '50013794', 'Avg grade': 27.0}
# {'_id': '50014157', 'Avg grade': 27.0}
# {'_id': '50013127', 'Avg grade': 27.0}
# {'_id': '50008861', 'Avg grade': 27.0}
# {'_id': '50014448', 'Avg grade': 27.0}
# {'_id': '50018185', 'Avg grade': 27.0}
# {'_id': '50007445', 'Avg grade': 27.0}
# {'_id': '50011046', 'Avg grade': 27.0}
# {'_id': '50012506', 'Avg grade': 27.0}
# {'_id': '50010058', 'Avg grade': 27.0}
# {'_id': '41416221', 'Avg grade': 27.0}
# {'_id': '50003732', 'Avg grade': 27.0}
# {'_id': '50011053', 'Avg grade': 27.0}
# {'_id': '50013096', 'Avg grade': 27.0}
# {'_id': '50005296', 'Avg grade': 27.0}
# {'_id': '41289382', 'Avg grade': 26.857142857142858}
# {'_id': '41373149', 'Avg grade': 26.8}
# {'_id': '41020284', 'Avg grade': 26.8}
# {'_id': '41645858', 'Avg grade': 26.8}
# {'_id': '41630632', 'Avg grade': 26.8}
# {'_id': '41686535', 'Avg grade': 26.75}
# {'_id': '41409894', 'Avg grade': 26.666666666666668}
# {'_id': '40596377', 'Avg grade': 26.666666666666668}
# {'_id': '41129343', 'Avg grade': 26.666666666666668}
# {'_id': '50000707', 'Avg grade': 26.666666666666668}
# {'_id': '50001415', 'Avg grade': 26.666666666666668}
# {'_id': '41317594', 'Avg grade': 26.6}
# {'_id': '41163308', 'Avg grade': 26.6}
# {'_id': '40923200', 'Avg grade': 26.6}
# {'_id': '41596841', 'Avg grade': 26.571428571428573}
# {'_id': '41080814', 'Avg grade': 26.571428571428573}
# {'_id': '50004251', 'Avg grade': 26.5}
# {'_id': '40584813', 'Avg grade': 26.5}
# {'_id': '50005362', 'Avg grade': 26.5}
# {'_id': '50001863', 'Avg grade': 26.5}
# {'_id': '41034526', 'Avg grade': 26.5}
# {'_id': '50003303', 'Avg grade': 26.5}
# {'_id': '50005601', 'Avg grade': 26.5}
# {'_id': '50005402', 'Avg grade': 26.5}
# {'_id': '50010946', 'Avg grade': 26.5}
# {'_id': '41491764', 'Avg grade': 26.4}
# {'_id': '41644539', 'Avg grade': 26.333333333333332}
# {'_id': '50000138', 'Avg grade': 26.333333333333332}
# {'_id': '41297769', 'Avg grade': 26.333333333333332}
# {'_id': '41608998', 'Avg grade': 26.333333333333332}
# {'_id': '41673468', 'Avg grade': 26.333333333333332}
# {'_id': '40580639', 'Avg grade': 26.2}
# {'_id': '41528486', 'Avg grade': 26.166666666666668}
# {'_id': '41078097', 'Avg grade': 26.166666666666668}
# {'_id': '41590267', 'Avg grade': 26.166666666666668}
# {'_id': '41239374', 'Avg grade': 26.125}
# {'_id': '50014362', 'Avg grade': 26.0}
# {'_id': '50013322', 'Avg grade': 26.0}
# {'_id': '50017279', 'Avg grade': 26.0}
# {'_id': '50006962', 'Avg grade': 26.0}
# {'_id': '41638828', 'Avg grade': 26.0}
# {'_id': '50018087', 'Avg grade': 26.0}
# {'_id': '41690391', 'Avg grade': 26.0}
# {'_id': '41539257', 'Avg grade': 26.0}
# {'_id': '50001985', 'Avg grade': 26.0}
# {'_id': '50010340', 'Avg grade': 26.0}
# {'_id': '50004673', 'Avg grade': 26.0}
# {'_id': '50016832', 'Avg grade': 26.0}
# {'_id': '50008374', 'Avg grade': 26.0}
# {'_id': '50010923', 'Avg grade': 26.0}
# {'_id': '50014330', 'Avg grade': 26.0}
# {'_id': '50012427', 'Avg grade': 26.0}
# {'_id': '40901214', 'Avg grade': 26.0}
# {'_id': '50010700', 'Avg grade': 26.0}
# {'_id': '50005232', 'Avg grade': 26.0}
# {'_id': '41174419', 'Avg grade': 26.0}
# {'_id': '41709385', 'Avg grade': 26.0}
# {'_id': '50008600', 'Avg grade': 26.0}
# {'_id': '50014982', 'Avg grade': 26.0}
# {'_id': '50013405', 'Avg grade': 26.0}
# {'_id': '50015648', 'Avg grade': 26.0}
# {'_id': '50007609', 'Avg grade': 26.0}
# {'_id': '50011247', 'Avg grade': 26.0}
# {'_id': '50012688', 'Avg grade': 26.0}
# {'_id': '50016857', 'Avg grade': 26.0}
# {'_id': '50014561', 'Avg grade': 26.0}
# {'_id': '50014708', 'Avg grade': 26.0}
# {'_id': '41176008', 'Avg grade': 26.0}
# {'_id': '40392721', 'Avg grade': 26.0}
# {'_id': '50016993', 'Avg grade': 26.0}
# {'_id': '50007871', 'Avg grade': 26.0}
# {'_id': '50014166', 'Avg grade': 26.0}
# {'_id': '50016871', 'Avg grade': 26.0}
# {'_id': '50011322', 'Avg grade': 26.0}
# {'_id': '50012869', 'Avg grade': 26.0}
# {'_id': '41194510', 'Avg grade': 26.0}
# {'_id': '41451842', 'Avg grade': 25.857142857142858}
# {'_id': '41083469', 'Avg grade': 25.833333333333332}
# {'_id': '40721121', 'Avg grade': 25.833333333333332}
# {'_id': '41646474', 'Avg grade': 25.833333333333332}
# {'_id': '41462643', 'Avg grade': 25.8}
# {'_id': '41620008', 'Avg grade': 25.8}
# {'_id': '41690085', 'Avg grade': 25.8}
# {'_id': '50000695', 'Avg grade': 25.75}
# {'_id': '50001166', 'Avg grade': 25.666666666666668}
# {'_id': '41135835', 'Avg grade': 25.666666666666668}
# {'_id': '41475257', 'Avg grade': 25.666666666666668}
# {'_id': '41459743', 'Avg grade': 25.666666666666668}
# {'_id': '41642333', 'Avg grade': 25.6}
# {'_id': '41391353', 'Avg grade': 25.5}
# {'_id': '40735965', 'Avg grade': 25.5}
# {'_id': '41660347', 'Avg grade': 25.5}
# {'_id': '41684379', 'Avg grade': 25.5}
# {'_id': '41605309', 'Avg grade': 25.4}
# {'_id': '50001688', 'Avg grade': 25.333333333333332}
# {'_id': '50001539', 'Avg grade': 25.333333333333332}
# {'_id': '41053105', 'Avg grade': 25.285714285714285}
# {'_id': '40582271', 'Avg grade': 25.285714285714285}
# {'_id': '41697314', 'Avg grade': 25.25}
# {'_id': '41004458', 'Avg grade': 25.25}
# {'_id': '41090495', 'Avg grade': 25.2}
# {'_id': '41231957', 'Avg grade': 25.166666666666668}
# {'_id': '41352974', 'Avg grade': 25.166666666666668}
# {'_id': '50013220', 'Avg grade': 25.0}
# {'_id': '50010657', 'Avg grade': 25.0}
# {'_id': '41626198', 'Avg grade': 25.0}
# {'_id': '50005224', 'Avg grade': 25.0}
# {'_id': '50012299', 'Avg grade': 25.0}
# {'_id': '50011504', 'Avg grade': 25.0}
# {'_id': '50013463', 'Avg grade': 25.0}
# {'_id': '50011024', 'Avg grade': 25.0}
# {'_id': '40515590', 'Avg grade': 25.0}
# {'_id': '41585245', 'Avg grade': 25.0}
# {'_id': '50008594', 'Avg grade': 25.0}
# {'_id': '50012808', 'Avg grade': 25.0}
# {'_id': '41653831', 'Avg grade': 25.0}
# {'_id': '41653879', 'Avg grade': 25.0}
# {'_id': '50013618', 'Avg grade': 25.0}
# {'_id': '50017275', 'Avg grade': 25.0}
# {'_id': '50006427', 'Avg grade': 25.0}
# {'_id': '50017819', 'Avg grade': 25.0}
# {'_id': '50005704', 'Avg grade': 25.0}
# {'_id': '50017937', 'Avg grade': 25.0}
# {'_id': '50006762', 'Avg grade': 25.0}
# {'_id': '50014686', 'Avg grade': 25.0}
# {'_id': '50010096', 'Avg grade': 25.0}
# {'_id': '50010176', 'Avg grade': 25.0}
# {'_id': '50009782', 'Avg grade': 25.0}
# {'_id': '50009465', 'Avg grade': 25.0}
# {'_id': '50009542', 'Avg grade': 25.0}
# {'_id': '50012767', 'Avg grade': 25.0}
# {'_id': '50014351', 'Avg grade': 25.0}
# {'_id': '50004483', 'Avg grade': 25.0}
# {'_id': '50004783', 'Avg grade': 25.0}
# {'_id': '50017879', 'Avg grade': 25.0}
# {'_id': '41271454', 'Avg grade': 25.0}
# {'_id': '50015486', 'Avg grade': 25.0}
# {'_id': '50000055', 'Avg grade': 25.0}
# {'_id': '41573063', 'Avg grade': 24.857142857142858}
# {'_id': '40743368', 'Avg grade': 24.833333333333332}
# {'_id': '41400682', 'Avg grade': 24.833333333333332}
# {'_id': '41350902', 'Avg grade': 24.833333333333332}
# {'_id': '41705634', 'Avg grade': 24.8}
# {'_id': '41594943', 'Avg grade': 24.75}
# {'_id': '41302781', 'Avg grade': 24.75}
# {'_id': '41401462', 'Avg grade': 24.75}
# {'_id': '41540476', 'Avg grade': 24.714285714285715}
# {'_id': '50001701', 'Avg grade': 24.666666666666668}
# {'_id': '41232102', 'Avg grade': 24.666666666666668}
# {'_id': '41661062', 'Avg grade': 24.666666666666668}
# {'_id': '41382079', 'Avg grade': 24.666666666666668}
# {'_id': '40877264', 'Avg grade': 24.666666666666668}
# {'_id': '41154370', 'Avg grade': 24.666666666666668}
# {'_id': '41286006', 'Avg grade': 24.666666666666668}
# {'_id': '41610168', 'Avg grade': 24.6}
# {'_id': '41346018', 'Avg grade': 24.6}
# {'_id': '41423851', 'Avg grade': 24.6}
# {'_id': '41661430', 'Avg grade': 24.5}
# {'_id': '41097273', 'Avg grade': 24.5}
# {'_id': '50001209', 'Avg grade': 24.5}
# {'_id': '50000220', 'Avg grade': 24.5}
# {'_id': '50004177', 'Avg grade': 24.5}
# {'_id': '41695136', 'Avg grade': 24.5}
# {'_id': '40379149', 'Avg grade': 24.5}
# {'_id': '41721094', 'Avg grade': 24.5}
# {'_id': '40676022', 'Avg grade': 24.428571428571427}
# {'_id': '41461218', 'Avg grade': 24.4}
# {'_id': '41720706', 'Avg grade': 24.4}
# {'_id': '40812483', 'Avg grade': 24.333333333333332}
# {'_id': '50002773', 'Avg grade': 24.333333333333332}
# {'_id': '41168180', 'Avg grade': 24.333333333333332}
# {'_id': '50002875', 'Avg grade': 24.333333333333332}
# {'_id': '40977865', 'Avg grade': 24.333333333333332}
# {'_id': '41497492', 'Avg grade': 24.285714285714285}
# {'_id': '41589689', 'Avg grade': 24.285714285714285}
# {'_id': '41631487', 'Avg grade': 24.25}
# {'_id': '41711623', 'Avg grade': 24.25}
# {'_id': '41681147', 'Avg grade': 24.25}
# {'_id': '40742158', 'Avg grade': 24.2}
# {'_id': '41301888', 'Avg grade': 24.2}
# {'_id': '41278255', 'Avg grade': 24.2}
# {'_id': '40561058', 'Avg grade': 24.166666666666668}
# {'_id': '41015667', 'Avg grade': 24.166666666666668}
# {'_id': '41054366', 'Avg grade': 24.166666666666668}
# {'_id': '40371419', 'Avg grade': 24.166666666666668}
# {'_id': '40381295', 'Avg grade': 24.142857142857142}
# {'_id': '50013780', 'Avg grade': 24.0}
# {'_id': '50011938', 'Avg grade': 24.0}
# {'_id': '50006348', 'Avg grade': 24.0}
# {'_id': '41699850', 'Avg grade': 24.0}
# {'_id': '50018415', 'Avg grade': 24.0}
# {'_id': '50015200', 'Avg grade': 24.0}
# {'_id': '40902021', 'Avg grade': 24.0}
# {'_id': '50017221', 'Avg grade': 24.0}
# {'_id': '41177205', 'Avg grade': 24.0}
# {'_id': '50010791', 'Avg grade': 24.0}
# {'_id': '50003668', 'Avg grade': 24.0}
# {'_id': '41387173', 'Avg grade': 24.0}
# {'_id': '50018345', 'Avg grade': 24.0}
# {'_id': '50016436', 'Avg grade': 24.0}
# {'_id': '50001460', 'Avg grade': 24.0}
# {'_id': '50017184', 'Avg grade': 24.0}
# {'_id': '50014044', 'Avg grade': 24.0}
# {'_id': '50014089', 'Avg grade': 24.0}
# {'_id': '50003086', 'Avg grade': 24.0}
# {'_id': '50015995', 'Avg grade': 24.0}
# {'_id': '50016992', 'Avg grade': 24.0}
# {'_id': '50002691', 'Avg grade': 24.0}
# {'_id': '41659174', 'Avg grade': 24.0}
# {'_id': '50012165', 'Avg grade': 24.0}
# {'_id': '50017347', 'Avg grade': 24.0}
# {'_id': '50008635', 'Avg grade': 24.0}
# {'_id': '50009774', 'Avg grade': 24.0}
# {'_id': '40576403', 'Avg grade': 24.0}
# {'_id': '50015191', 'Avg grade': 24.0}
# {'_id': '41718951', 'Avg grade': 24.0}
# {'_id': '50016263', 'Avg grade': 24.0}
# {'_id': '50016964', 'Avg grade': 24.0}
# {'_id': '50006266', 'Avg grade': 24.0}
# {'_id': '50006281', 'Avg grade': 24.0}
# {'_id': '50015159', 'Avg grade': 24.0}
# {'_id': '50012705', 'Avg grade': 24.0}
# {'_id': '50013333', 'Avg grade': 24.0}
# {'_id': '50002990', 'Avg grade': 24.0}
# {'_id': '41514954', 'Avg grade': 24.0}
# {'_id': '50016088', 'Avg grade': 24.0}
# {'_id': '40711118', 'Avg grade': 24.0}
# {'_id': '50008858', 'Avg grade': 24.0}
# {'_id': '41425640', 'Avg grade': 24.0}
# {'_id': '50015452', 'Avg grade': 24.0}
# {'_id': '50005347', 'Avg grade': 24.0}
# {'_id': '50011101', 'Avg grade': 24.0}
# {'_id': '41385711', 'Avg grade': 24.0}
# {'_id': '41686215', 'Avg grade': 24.0}
# {'_id': '41559322', 'Avg grade': 24.0}
# {'_id': '50014193', 'Avg grade': 24.0}
# {'_id': '50016982', 'Avg grade': 24.0}
# {'_id': '50001549', 'Avg grade': 24.0}
# {'_id': '50012353', 'Avg grade': 24.0}
# {'_id': '50017190', 'Avg grade': 24.0}
# {'_id': '40397520', 'Avg grade': 24.0}
# {'_id': '50018143', 'Avg grade': 24.0}
# {'_id': '50014537', 'Avg grade': 24.0}
# {'_id': '41707666', 'Avg grade': 24.0}
# {'_id': '50003580', 'Avg grade': 24.0}
# {'_id': '41342422', 'Avg grade': 23.857142857142858}
# {'_id': '40548766', 'Avg grade': 23.857142857142858}
# {'_id': '41380719', 'Avg grade': 23.833333333333332}
# {'_id': '40878507', 'Avg grade': 23.8}
# {'_id': '41408932', 'Avg grade': 23.8}
# {'_id': '41694992', 'Avg grade': 23.75}
# {'_id': '41001107', 'Avg grade': 23.75}
# {'_id': '41172677', 'Avg grade': 23.75}
# {'_id': '41476799', 'Avg grade': 23.666666666666668}
# {'_id': '50007321', 'Avg grade': 23.666666666666668}
# {'_id': '41644596', 'Avg grade': 23.666666666666668}
# {'_id': '41373941', 'Avg grade': 23.6}
# {'_id': '41541377', 'Avg grade': 23.571428571428573}
# {'_id': '41242254', 'Avg grade': 23.571428571428573}
# {'_id': '40864145', 'Avg grade': 23.571428571428573}
# {'_id': '41170643', 'Avg grade': 23.5}
# {'_id': '41585425', 'Avg grade': 23.5}
# {'_id': '50005509', 'Avg grade': 23.5}
# {'_id': '50009763', 'Avg grade': 23.5}
# {'_id': '41599396', 'Avg grade': 23.5}
# {'_id': '40370759', 'Avg grade': 23.5}
# {'_id': '40667358', 'Avg grade': 23.5}
# {'_id': '41704239', 'Avg grade': 23.5}
# {'_id': '50005403', 'Avg grade': 23.5}
# {'_id': '50001655', 'Avg grade': 23.5}
# {'_id': '50001836', 'Avg grade': 23.5}
# {'_id': '41660608', 'Avg grade': 23.5}
# {'_id': '50002191', 'Avg grade': 23.5}
# {'_id': '50010599', 'Avg grade': 23.5}
# {'_id': '41437350', 'Avg grade': 23.428571428571427}
# {'_id': '40741967', 'Avg grade': 23.428571428571427}
# {'_id': '41561455', 'Avg grade': 23.4}
# {'_id': '41431171', 'Avg grade': 23.4}
# {'_id': '40572960', 'Avg grade': 23.4}
# {'_id': '40401834', 'Avg grade': 23.333333333333332}
# {'_id': '41634954', 'Avg grade': 23.333333333333332}
# {'_id': '50000456', 'Avg grade': 23.333333333333332}
# {'_id': '41497126', 'Avg grade': 23.333333333333332}
# {'_id': '41703048', 'Avg grade': 23.333333333333332}
# {'_id': '41389547', 'Avg grade': 23.333333333333332}
# {'_id': '40687217', 'Avg grade': 23.333333333333332}
# {'_id': '41125485', 'Avg grade': 23.333333333333332}
# {'_id': '41281702', 'Avg grade': 23.25}
# {'_id': '41410655', 'Avg grade': 23.25}
# {'_id': '40871961', 'Avg grade': 23.2}
# {'_id': '41250480', 'Avg grade': 23.2}
# {'_id': '41690948', 'Avg grade': 23.2}
# {'_id': '41572685', 'Avg grade': 23.2}
# {'_id': '41371241', 'Avg grade': 23.2}
# {'_id': '41661153', 'Avg grade': 23.2}
# {'_id': '41423676', 'Avg grade': 23.2}
# {'_id': '41319774', 'Avg grade': 23.2}
# {'_id': '41253814', 'Avg grade': 23.166666666666668}
# {'_id': '41236269', 'Avg grade': 23.166666666666668}
# {'_id': '41560432', 'Avg grade': 23.166666666666668}
# {'_id': '40881088', 'Avg grade': 23.166666666666668}
# {'_id': '41425803', 'Avg grade': 23.166666666666668}
# {'_id': '41595287', 'Avg grade': 23.166666666666668}
# {'_id': '50015416', 'Avg grade': 23.0}
# {'_id': '50004057', 'Avg grade': 23.0}
# {'_id': '50018013', 'Avg grade': 23.0}
# {'_id': '50017240', 'Avg grade': 23.0}
# {'_id': '41701897', 'Avg grade': 23.0}
# {'_id': '50013098', 'Avg grade': 23.0}
# {'_id': '41322801', 'Avg grade': 23.0}
# {'_id': '50017072', 'Avg grade': 23.0}
# {'_id': '50017808', 'Avg grade': 23.0}
# {'_id': '41030982', 'Avg grade': 23.0}
# {'_id': '41503546', 'Avg grade': 23.0}
# {'_id': '50004782', 'Avg grade': 23.0}
# {'_id': '50012282', 'Avg grade': 23.0}
# {'_id': '50002936', 'Avg grade': 23.0}
# {'_id': '50011908', 'Avg grade': 23.0}
# {'_id': '50015061', 'Avg grade': 23.0}
# {'_id': '50002766', 'Avg grade': 23.0}
# {'_id': '50001536', 'Avg grade': 23.0}
# {'_id': '50005061', 'Avg grade': 23.0}
# {'_id': '50011159', 'Avg grade': 23.0}
# {'_id': '41176438', 'Avg grade': 23.0}
# {'_id': '50017934', 'Avg grade': 23.0}
# {'_id': '40969562', 'Avg grade': 23.0}
# {'_id': '50017733', 'Avg grade': 23.0}
# {'_id': '50011230', 'Avg grade': 23.0}
# {'_id': '50010504', 'Avg grade': 23.0}
# {'_id': '41315168', 'Avg grade': 23.0}
# {'_id': '50016672', 'Avg grade': 23.0}
# {'_id': '41699229', 'Avg grade': 23.0}
# {'_id': '50017042', 'Avg grade': 23.0}
# {'_id': '50006824', 'Avg grade': 23.0}
# {'_id': '50010991', 'Avg grade': 23.0}
# {'_id': '50017877', 'Avg grade': 23.0}
# {'_id': '41444418', 'Avg grade': 23.0}
# {'_id': '40401543', 'Avg grade': 23.0}
# {'_id': '50011372', 'Avg grade': 23.0}
# {'_id': '41304510', 'Avg grade': 23.0}
# {'_id': '41318801', 'Avg grade': 23.0}
# {'_id': '41706711', 'Avg grade': 23.0}
# {'_id': '41261509', 'Avg grade': 23.0}
# {'_id': '50006377', 'Avg grade': 23.0}
# {'_id': '41720168', 'Avg grade': 23.0}
# {'_id': '50016212', 'Avg grade': 23.0}
# {'_id': '41043494', 'Avg grade': 23.0}
# {'_id': '50018404', 'Avg grade': 23.0}
# {'_id': '50017921', 'Avg grade': 23.0}
# {'_id': '50008351', 'Avg grade': 23.0}
# {'_id': '50015197', 'Avg grade': 23.0}
# {'_id': '50011340', 'Avg grade': 23.0}
# {'_id': '41678328', 'Avg grade': 23.0}
# {'_id': '41457520', 'Avg grade': 23.0}
# {'_id': '50000888', 'Avg grade': 23.0}
# {'_id': '50012076', 'Avg grade': 23.0}
# {'_id': '50014495', 'Avg grade': 23.0}
# {'_id': '50008913', 'Avg grade': 23.0}
# {'_id': '50015179', 'Avg grade': 23.0}
# {'_id': '50011786', 'Avg grade': 23.0}
# {'_id': '50018078', 'Avg grade': 23.0}
# {'_id': '50017262', 'Avg grade': 23.0}
# {'_id': '50016144', 'Avg grade': 23.0}
# {'_id': '40510969', 'Avg grade': 23.0}
# {'_id': '41707556', 'Avg grade': 23.0}
# {'_id': '50016893', 'Avg grade': 23.0}
# {'_id': '50017265', 'Avg grade': 23.0}
# {'_id': '50008840', 'Avg grade': 23.0}
# {'_id': '50015448', 'Avg grade': 23.0}
# {'_id': '50012306', 'Avg grade': 23.0}
# {'_id': '50005865', 'Avg grade': 23.0}
# {'_id': '40944945', 'Avg grade': 23.0}
# {'_id': '41466937', 'Avg grade': 22.875}
# {'_id': '41576836', 'Avg grade': 22.857142857142858}
# {'_id': '41608413', 'Avg grade': 22.833333333333332}
# {'_id': '41088824', 'Avg grade': 22.833333333333332}
# {'_id': '41317579', 'Avg grade': 22.833333333333332}
# {'_id': '40826684', 'Avg grade': 22.833333333333332}
# {'_id': '41620272', 'Avg grade': 22.833333333333332}
# {'_id': '41686353', 'Avg grade': 22.8}
# {'_id': '41680137', 'Avg grade': 22.8}
# {'_id': '41008526', 'Avg grade': 22.8}
# {'_id': '41624737', 'Avg grade': 22.8}
# {'_id': '40707194', 'Avg grade': 22.8}
# {'_id': '41719668', 'Avg grade': 22.8}
# {'_id': '41625263', 'Avg grade': 22.8}
# {'_id': '41573931', 'Avg grade': 22.75}
# {'_id': '41247170', 'Avg grade': 22.75}
# {'_id': '40869524', 'Avg grade': 22.75}
# {'_id': '41220492', 'Avg grade': 22.75}
# {'_id': '41155953', 'Avg grade': 22.75}
# {'_id': '41251199', 'Avg grade': 22.75}
# {'_id': '40852659', 'Avg grade': 22.714285714285715}
# {'_id': '41542304', 'Avg grade': 22.666666666666668}
# {'_id': '41531279', 'Avg grade': 22.666666666666668}
# {'_id': '41586091', 'Avg grade': 22.666666666666668}
# {'_id': '50002405', 'Avg grade': 22.666666666666668}
# {'_id': '40968428', 'Avg grade': 22.666666666666668}
# {'_id': '41551620', 'Avg grade': 22.666666666666668}
# {'_id': '50000720', 'Avg grade': 22.666666666666668}
# {'_id': '41563476', 'Avg grade': 22.666666666666668}
# {'_id': '50001483', 'Avg grade': 22.666666666666668}
# {'_id': '50001308', 'Avg grade': 22.666666666666668}
# {'_id': '40393688', 'Avg grade': 22.625}
# {'_id': '41676147', 'Avg grade': 22.6}
# {'_id': '40962335', 'Avg grade': 22.6}
# {'_id': '41351576', 'Avg grade': 22.6}
# {'_id': '41002789', 'Avg grade': 22.6}
# {'_id': '41400575', 'Avg grade': 22.6}
# {'_id': '41400378', 'Avg grade': 22.6}
# {'_id': '41626911', 'Avg grade': 22.6}
# {'_id': '41464310', 'Avg grade': 22.6}
# {'_id': '41406895', 'Avg grade': 22.6}
# {'_id': '41615409', 'Avg grade': 22.6}
# {'_id': '41097286', 'Avg grade': 22.571428571428573}
# {'_id': '41289885', 'Avg grade': 22.571428571428573}
# {'_id': '50003206', 'Avg grade': 22.5}
# {'_id': '41387224', 'Avg grade': 22.5}
# {'_id': '50008709', 'Avg grade': 22.5}
# {'_id': '40871070', 'Avg grade': 22.5}
# {'_id': '41677816', 'Avg grade': 22.5}
# {'_id': '41467708', 'Avg grade': 22.5}
# {'_id': '41304667', 'Avg grade': 22.5}
# {'_id': '50003200', 'Avg grade': 22.5}
# {'_id': '50001215', 'Avg grade': 22.5}
# {'_id': '50003859', 'Avg grade': 22.5}
# {'_id': '41692410', 'Avg grade': 22.5}
# {'_id': '41267759', 'Avg grade': 22.5}
# {'_id': '50009366', 'Avg grade': 22.5}
# {'_id': '50007359', 'Avg grade': 22.5}
# {'_id': '41665161', 'Avg grade': 22.4}
# {'_id': '40798514', 'Avg grade': 22.4}
# {'_id': '41657465', 'Avg grade': 22.4}
# {'_id': '41354191', 'Avg grade': 22.4}
# {'_id': '41638762', 'Avg grade': 22.4}
# {'_id': '50000005', 'Avg grade': 22.4}
# {'_id': '41582626', 'Avg grade': 22.4}
# {'_id': '50000543', 'Avg grade': 22.333333333333332}
# {'_id': '41338145', 'Avg grade': 22.333333333333332}
# {'_id': '41683751', 'Avg grade': 22.333333333333332}
# {'_id': '50001312', 'Avg grade': 22.333333333333332}
# {'_id': '41710596', 'Avg grade': 22.333333333333332}
# {'_id': '41686846', 'Avg grade': 22.333333333333332}
# {'_id': '41717188', 'Avg grade': 22.333333333333332}
# {'_id': '50010039', 'Avg grade': 22.333333333333332}
# {'_id': '41143170', 'Avg grade': 22.333333333333332}
# {'_id': '41481803', 'Avg grade': 22.333333333333332}
# {'_id': '41193955', 'Avg grade': 22.333333333333332}
# {'_id': '41653387', 'Avg grade': 22.333333333333332}
# {'_id': '41541795', 'Avg grade': 22.333333333333332}
# {'_id': '41639167', 'Avg grade': 22.333333333333332}
# {'_id': '41388484', 'Avg grade': 22.25}
# {'_id': '41068173', 'Avg grade': 22.25}
# {'_id': '41685035', 'Avg grade': 22.25}
# {'_id': '41690699', 'Avg grade': 22.25}
# {'_id': '41089604', 'Avg grade': 22.25}
# {'_id': '41688594', 'Avg grade': 22.25}
# {'_id': '41705032', 'Avg grade': 22.25}
# {'_id': '41446312', 'Avg grade': 22.25}
# {'_id': '40861669', 'Avg grade': 22.25}
# {'_id': '41545094', 'Avg grade': 22.2}
# {'_id': '41504651', 'Avg grade': 22.2}
# {'_id': '40402428', 'Avg grade': 22.2}
# {'_id': '41251209', 'Avg grade': 22.2}
# {'_id': '41288811', 'Avg grade': 22.166666666666668}
# {'_id': '41486929', 'Avg grade': 22.166666666666668}
# {'_id': '41143058', 'Avg grade': 22.166666666666668}
# {'_id': '41069478', 'Avg grade': 22.166666666666668}
# {'_id': '41650784', 'Avg grade': 22.166666666666668}
# {'_id': '50012067', 'Avg grade': 22.0}
# {'_id': '50012530', 'Avg grade': 22.0}
# {'_id': '50014422', 'Avg grade': 22.0}
# {'_id': '50009775', 'Avg grade': 22.0}
# {'_id': '50014384', 'Avg grade': 22.0}
# {'_id': '50010580', 'Avg grade': 22.0}
# {'_id': '50017444', 'Avg grade': 22.0}
# {'_id': '50012601', 'Avg grade': 22.0}
# {'_id': '41714810', 'Avg grade': 22.0}
# {'_id': '50016679', 'Avg grade': 22.0}
# {'_id': '50011269', 'Avg grade': 22.0}
# {'_id': '50015403', 'Avg grade': 22.0}
# {'_id': '50017706', 'Avg grade': 22.0}
# {'_id': '41457023', 'Avg grade': 22.0}
# {'_id': '50017207', 'Avg grade': 22.0}
# {'_id': '50016289', 'Avg grade': 22.0}
# {'_id': '50013609', 'Avg grade': 22.0}
# {'_id': '50013363', 'Avg grade': 22.0}
# {'_id': '41699594', 'Avg grade': 22.0}
# {'_id': '50011532', 'Avg grade': 22.0}
# {'_id': '41168603', 'Avg grade': 22.0}
# {'_id': '50007631', 'Avg grade': 22.0}
# {'_id': '50013372', 'Avg grade': 22.0}
# {'_id': '50018503', 'Avg grade': 22.0}
# {'_id': '50015178', 'Avg grade': 22.0}
# {'_id': '50007076', 'Avg grade': 22.0}
# {'_id': '50009783', 'Avg grade': 22.0}
# {'_id': '41533022', 'Avg grade': 22.0}
# {'_id': '41343720', 'Avg grade': 22.0}
# {'_id': '50018254', 'Avg grade': 22.0}
# {'_id': '50015023', 'Avg grade': 22.0}
# {'_id': '50011454', 'Avg grade': 22.0}
# {'_id': '50005089', 'Avg grade': 22.0}
# {'_id': '50004900', 'Avg grade': 22.0}
# {'_id': '50001538', 'Avg grade': 22.0}
# {'_id': '50016840', 'Avg grade': 22.0}
# {'_id': '50006488', 'Avg grade': 22.0}
# {'_id': '50014554', 'Avg grade': 22.0}
# {'_id': '50017126', 'Avg grade': 22.0}
# {'_id': '50005127', 'Avg grade': 22.0}
# {'_id': '41563975', 'Avg grade': 22.0}
# {'_id': '50013095', 'Avg grade': 22.0}
# {'_id': '50017199', 'Avg grade': 22.0}
# {'_id': '50002760', 'Avg grade': 22.0}
# {'_id': '41416480', 'Avg grade': 22.0}
# {'_id': '41684209', 'Avg grade': 22.0}
# {'_id': '41713405', 'Avg grade': 22.0}
# {'_id': '50011690', 'Avg grade': 22.0}
# {'_id': '40376944', 'Avg grade': 22.0}
# {'_id': '50010974', 'Avg grade': 22.0}
# {'_id': '50006636', 'Avg grade': 22.0}
# {'_id': '50015697', 'Avg grade': 22.0}
# {'_id': '50015533', 'Avg grade': 22.0}
# {'_id': '50001656', 'Avg grade': 22.0}
# {'_id': '41211538', 'Avg grade': 22.0}
# {'_id': '41667050', 'Avg grade': 22.0}
# {'_id': '50004975', 'Avg grade': 22.0}
# {'_id': '41642835', 'Avg grade': 22.0}
# {'_id': '50014008', 'Avg grade': 22.0}
# {'_id': '50004182', 'Avg grade': 22.0}
# {'_id': '50016021', 'Avg grade': 22.0}
# {'_id': '40383009', 'Avg grade': 22.0}
# {'_id': '41665733', 'Avg grade': 22.0}
# {'_id': '50017015', 'Avg grade': 22.0}
# {'_id': '50016676', 'Avg grade': 22.0}
# {'_id': '50011573', 'Avg grade': 22.0}
# {'_id': '50011580', 'Avg grade': 22.0}
# {'_id': '41614971', 'Avg grade': 22.0}
# {'_id': '50009238', 'Avg grade': 22.0}
# {'_id': '41203533', 'Avg grade': 21.857142857142858}
# {'_id': '41265805', 'Avg grade': 21.857142857142858}
# {'_id': '41632951', 'Avg grade': 21.833333333333332}
# {'_id': '41397145', 'Avg grade': 21.833333333333332}
# {'_id': '41430562', 'Avg grade': 21.8}
# {'_id': '41249652', 'Avg grade': 21.8}
# {'_id': '41627976', 'Avg grade': 21.8}
# {'_id': '41420758', 'Avg grade': 21.8}
# {'_id': '41257223', 'Avg grade': 21.8}
# {'_id': '41460032', 'Avg grade': 21.8}
# {'_id': '40718497', 'Avg grade': 21.8}
# {'_id': '41224979', 'Avg grade': 21.8}
# {'_id': '41687169', 'Avg grade': 21.75}
# {'_id': '41315553', 'Avg grade': 21.75}
# {'_id': '41523349', 'Avg grade': 21.75}
# {'_id': '50000202', 'Avg grade': 21.75}
# {'_id': '40941749', 'Avg grade': 21.75}
# {'_id': '41528853', 'Avg grade': 21.714285714285715}
# {'_id': '41705745', 'Avg grade': 21.666666666666668}
# {'_id': '41566669', 'Avg grade': 21.666666666666668}
# {'_id': '50002071', 'Avg grade': 21.666666666666668}
# {'_id': '41394680', 'Avg grade': 21.666666666666668}
# {'_id': '41544554', 'Avg grade': 21.666666666666668}
# {'_id': '41410290', 'Avg grade': 21.666666666666668}
# {'_id': '40401000', 'Avg grade': 21.666666666666668}
# {'_id': '41210716', 'Avg grade': 21.666666666666668}
# {'_id': '41252980', 'Avg grade': 21.666666666666668}
# {'_id': '50004707', 'Avg grade': 21.666666666666668}
# {'_id': '41712232', 'Avg grade': 21.666666666666668}
# {'_id': '41607793', 'Avg grade': 21.625}
# {'_id': '41428366', 'Avg grade': 21.6}
# {'_id': '40381420', 'Avg grade': 21.6}
# {'_id': '41464143', 'Avg grade': 21.6}
# {'_id': '41673898', 'Avg grade': 21.6}
# {'_id': '41116368', 'Avg grade': 21.6}
# {'_id': '41473028', 'Avg grade': 21.6}
# {'_id': '41431518', 'Avg grade': 21.571428571428573}
# {'_id': '41225253', 'Avg grade': 21.5}
# {'_id': '41599911', 'Avg grade': 21.5}
# {'_id': '41621175', 'Avg grade': 21.5}
# {'_id': '40727249', 'Avg grade': 21.5}
# {'_id': '40482841', 'Avg grade': 21.5}
# {'_id': '50003333', 'Avg grade': 21.5}
# {'_id': '40364576', 'Avg grade': 21.5}
# {'_id': '50001585', 'Avg grade': 21.5}
# {'_id': '41637352', 'Avg grade': 21.5}
# {'_id': '41479899', 'Avg grade': 21.5}
# {'_id': '50007077', 'Avg grade': 21.5}
# {'_id': '41722730', 'Avg grade': 21.5}
# {'_id': '41453018', 'Avg grade': 21.5}
# {'_id': '40365280', 'Avg grade': 21.5}
# {'_id': '50000198', 'Avg grade': 21.5}
# {'_id': '41708744', 'Avg grade': 21.5}
# {'_id': '40376933', 'Avg grade': 21.5}
# {'_id': '40791454', 'Avg grade': 21.5}
# {'_id': '40392685', 'Avg grade': 21.5}
# {'_id': '50006080', 'Avg grade': 21.5}
# {'_id': '50006096', 'Avg grade': 21.5}
# {'_id': '41650721', 'Avg grade': 21.5}
# {'_id': '50003627', 'Avg grade': 21.5}
# {'_id': '41388810', 'Avg grade': 21.5}
# {'_id': '41037812', 'Avg grade': 21.5}
# {'_id': '50003218', 'Avg grade': 21.5}
# {'_id': '41533270', 'Avg grade': 21.5}
# {'_id': '50004299', 'Avg grade': 21.5}
# {'_id': '41600476', 'Avg grade': 21.5}
# {'_id': '41722626', 'Avg grade': 21.5}
# {'_id': '50005934', 'Avg grade': 21.5}
# {'_id': '41315723', 'Avg grade': 21.428571428571427}
# {'_id': '41310578', 'Avg grade': 21.428571428571427}
# {'_id': '41162660', 'Avg grade': 21.428571428571427}
# {'_id': '41079528', 'Avg grade': 21.428571428571427}
# {'_id': '41514254', 'Avg grade': 21.428571428571427}
# {'_id': '41057024', 'Avg grade': 21.4}
# {'_id': '41457630', 'Avg grade': 21.4}
# {'_id': '41641589', 'Avg grade': 21.4}
# {'_id': '41525492', 'Avg grade': 21.4}
# {'_id': '41228956', 'Avg grade': 21.4}
# {'_id': '41123837', 'Avg grade': 21.4}
# {'_id': '41478306', 'Avg grade': 21.4}
# {'_id': '40618281', 'Avg grade': 21.4}
# {'_id': '40658944', 'Avg grade': 21.4}
# {'_id': '40950399', 'Avg grade': 21.4}
# {'_id': '50001637', 'Avg grade': 21.333333333333332}
# {'_id': '41700187', 'Avg grade': 21.333333333333332}
# {'_id': '41491419', 'Avg grade': 21.333333333333332}
# {'_id': '41623638', 'Avg grade': 21.333333333333332}
# {'_id': '41678959', 'Avg grade': 21.333333333333332}
# {'_id': '41706722', 'Avg grade': 21.333333333333332}
# {'_id': '41598995', 'Avg grade': 21.285714285714285}
# {'_id': '41011887', 'Avg grade': 21.285714285714285}
# {'_id': '41677255', 'Avg grade': 21.25}
# {'_id': '50003434', 'Avg grade': 21.25}
# {'_id': '41669112', 'Avg grade': 21.25}
# {'_id': '41423962', 'Avg grade': 21.25}
# {'_id': '41695827', 'Avg grade': 21.25}
# {'_id': '41433069', 'Avg grade': 21.25}
# {'_id': '41633807', 'Avg grade': 21.25}
# {'_id': '40568285', 'Avg grade': 21.2}
# {'_id': '41423445', 'Avg grade': 21.2}
# {'_id': '41697391', 'Avg grade': 21.2}
# {'_id': '40743578', 'Avg grade': 21.2}
# {'_id': '41645211', 'Avg grade': 21.2}
# {'_id': '40389701', 'Avg grade': 21.166666666666668}
# {'_id': '40729582', 'Avg grade': 21.166666666666668}
# {'_id': '41001024', 'Avg grade': 21.166666666666668}
# {'_id': '40918176', 'Avg grade': 21.166666666666668}
# {'_id': '41167466', 'Avg grade': 21.166666666666668}
# {'_id': '40399334', 'Avg grade': 21.166666666666668}
# {'_id': '41593344', 'Avg grade': 21.166666666666668}
# {'_id': '41479499', 'Avg grade': 21.142857142857142}
# {'_id': '41632866', 'Avg grade': 21.142857142857142}
# {'_id': '40916719', 'Avg grade': 21.142857142857142}
# {'_id': '41592230', 'Avg grade': 21.142857142857142}
# {'_id': '41582818', 'Avg grade': 21.125}
# {'_id': '50008256', 'Avg grade': 21.0}
# {'_id': '50001430', 'Avg grade': 21.0}
# {'_id': '41662941', 'Avg grade': 21.0}
# {'_id': '50015634', 'Avg grade': 21.0}
# {'_id': '41327097', 'Avg grade': 21.0}
# {'_id': '50015103', 'Avg grade': 21.0}
# {'_id': '41648717', 'Avg grade': 21.0}
# {'_id': '41024190', 'Avg grade': 21.0}
# {'_id': '41529681', 'Avg grade': 21.0}
# {'_id': '40825792', 'Avg grade': 21.0}
# {'_id': '50017235', 'Avg grade': 21.0}
# {'_id': '50010333', 'Avg grade': 21.0}
# {'_id': '41100434', 'Avg grade': 21.0}
# {'_id': '50003485', 'Avg grade': 21.0}
# {'_id': '50009176', 'Avg grade': 21.0}
# {'_id': '50007626', 'Avg grade': 21.0}
# {'_id': '50010350', 'Avg grade': 21.0}
# {'_id': '50017525', 'Avg grade': 21.0}
# {'_id': '50012159', 'Avg grade': 21.0}
# {'_id': '50013970', 'Avg grade': 21.0}
# {'_id': '50015854', 'Avg grade': 21.0}
# {'_id': '41532206', 'Avg grade': 21.0}
# {'_id': '50012922', 'Avg grade': 21.0}
# {'_id': '50011127', 'Avg grade': 21.0}
# {'_id': '41391829', 'Avg grade': 21.0}
# {'_id': '40988278', 'Avg grade': 21.0}
# {'_id': '50005498', 'Avg grade': 21.0}
# {'_id': '41650465', 'Avg grade': 21.0}
# {'_id': '50009813', 'Avg grade': 21.0}
# {'_id': '50001969', 'Avg grade': 21.0}
# {'_id': '50017472', 'Avg grade': 21.0}
# {'_id': '41293635', 'Avg grade': 21.0}
# {'_id': '50017366', 'Avg grade': 21.0}
# {'_id': '50017334', 'Avg grade': 21.0}
# {'_id': '41387239', 'Avg grade': 21.0}
# {'_id': '50017000', 'Avg grade': 21.0}
# {'_id': '40525767', 'Avg grade': 21.0}
# {'_id': '50018008', 'Avg grade': 21.0}
# {'_id': '41690381', 'Avg grade': 21.0}
# {'_id': '41639035', 'Avg grade': 21.0}
# {'_id': '41697740', 'Avg grade': 21.0}
# {'_id': '41523593', 'Avg grade': 21.0}
# {'_id': '50005707', 'Avg grade': 21.0}
# {'_id': '41672217', 'Avg grade': 21.0}
# {'_id': '40997642', 'Avg grade': 21.0}
# {'_id': '41542520', 'Avg grade': 21.0}
# {'_id': '41710480', 'Avg grade': 21.0}
# {'_id': '50004219', 'Avg grade': 21.0}
# {'_id': '41696147', 'Avg grade': 21.0}
# {'_id': '41139255', 'Avg grade': 21.0}
# {'_id': '41370355', 'Avg grade': 21.0}
# {'_id': '50003404', 'Avg grade': 21.0}
# {'_id': '41345855', 'Avg grade': 21.0}
# {'_id': '41085065', 'Avg grade': 21.0}
# {'_id': '50013998', 'Avg grade': 21.0}
# {'_id': '41562311', 'Avg grade': 21.0}
# {'_id': '50014875', 'Avg grade': 21.0}
# {'_id': '41409233', 'Avg grade': 21.0}
# {'_id': '40395935', 'Avg grade': 21.0}
# {'_id': '50003897', 'Avg grade': 21.0}
# {'_id': '50011935', 'Avg grade': 21.0}
# {'_id': '50009470', 'Avg grade': 21.0}
# {'_id': '50004130', 'Avg grade': 21.0}
# {'_id': '50005925', 'Avg grade': 21.0}
# {'_id': '50005243', 'Avg grade': 21.0}
# {'_id': '41044065', 'Avg grade': 21.0}
# {'_id': '50011507', 'Avg grade': 21.0}
# {'_id': '50009496', 'Avg grade': 21.0}
# {'_id': '50012031', 'Avg grade': 21.0}
# {'_id': '50000188', 'Avg grade': 21.0}
# {'_id': '50014589', 'Avg grade': 21.0}
# {'_id': '40535512', 'Avg grade': 21.0}
# {'_id': '50015186', 'Avg grade': 21.0}
# {'_id': '41648118', 'Avg grade': 21.0}
# {'_id': '41632066', 'Avg grade': 21.0}
# {'_id': '41596870', 'Avg grade': 20.857142857142858}
# {'_id': '40990663', 'Avg grade': 20.857142857142858}
# {'_id': '41521827', 'Avg grade': 20.857142857142858}
# {'_id': '41631760', 'Avg grade': 20.833333333333332}
# {'_id': '41369316', 'Avg grade': 20.833333333333332}
# {'_id': '41344604', 'Avg grade': 20.833333333333332}
# {'_id': '41160401', 'Avg grade': 20.833333333333332}
# {'_id': '40424633', 'Avg grade': 20.833333333333332}
# {'_id': '40806489', 'Avg grade': 20.833333333333332}
# {'_id': '40994897', 'Avg grade': 20.833333333333332}
# {'_id': '41038028', 'Avg grade': 20.8}
# {'_id': '41506401', 'Avg grade': 20.8}
# {'_id': '41647017', 'Avg grade': 20.8}
# {'_id': '41134212', 'Avg grade': 20.8}
# {'_id': '41598152', 'Avg grade': 20.8}
# {'_id': '41588267', 'Avg grade': 20.8}
# {'_id': '41432865', 'Avg grade': 20.8}
# {'_id': '41579300', 'Avg grade': 20.8}
# {'_id': '41586172', 'Avg grade': 20.75}
# {'_id': '41709614', 'Avg grade': 20.75}
# {'_id': '41117663', 'Avg grade': 20.75}
# {'_id': '41511984', 'Avg grade': 20.75}
# {'_id': '41525509', 'Avg grade': 20.75}
# {'_id': '40605862', 'Avg grade': 20.75}
# {'_id': '41685081', 'Avg grade': 20.75}
# {'_id': '50001125', 'Avg grade': 20.75}
# {'_id': '41564527', 'Avg grade': 20.714285714285715}
# {'_id': '41652417', 'Avg grade': 20.714285714285715}
# {'_id': '41547121', 'Avg grade': 20.714285714285715}
# {'_id': '40400561', 'Avg grade': 20.714285714285715}
# {'_id': '41257226', 'Avg grade': 20.714285714285715}
# {'_id': '40386927', 'Avg grade': 20.666666666666668}
# {'_id': '41679503', 'Avg grade': 20.666666666666668}
# {'_id': '40870509', 'Avg grade': 20.666666666666668}
# {'_id': '41151295', 'Avg grade': 20.666666666666668}
# {'_id': '40395858', 'Avg grade': 20.666666666666668}
# {'_id': '41318313', 'Avg grade': 20.666666666666668}
# {'_id': '41692313', 'Avg grade': 20.666666666666668}
# {'_id': '41475322', 'Avg grade': 20.666666666666668}
# {'_id': '41709379', 'Avg grade': 20.666666666666668}
# {'_id': '41473217', 'Avg grade': 20.666666666666668}
# {'_id': '41297604', 'Avg grade': 20.666666666666668}
# {'_id': '41534408', 'Avg grade': 20.666666666666668}
# {'_id': '41715835', 'Avg grade': 20.666666666666668}
# {'_id': '41454213', 'Avg grade': 20.666666666666668}
# {'_id': '41271436', 'Avg grade': 20.666666666666668}
# {'_id': '41010509', 'Avg grade': 20.666666666666668}
# {'_id': '41268795', 'Avg grade': 20.666666666666668}
# {'_id': '40884999', 'Avg grade': 20.6}
# {'_id': '40397763', 'Avg grade': 20.6}
# {'_id': '41092403', 'Avg grade': 20.6}
# {'_id': '41470710', 'Avg grade': 20.6}
# {'_id': '41019412', 'Avg grade': 20.6}
# {'_id': '41585774', 'Avg grade': 20.6}
# {'_id': '41525452', 'Avg grade': 20.6}
# {'_id': '41615635', 'Avg grade': 20.571428571428573}
# {'_id': '50001908', 'Avg grade': 20.5}
# {'_id': '50005948', 'Avg grade': 20.5}
# {'_id': '50001069', 'Avg grade': 20.5}
# {'_id': '40636533', 'Avg grade': 20.5}
# {'_id': '41480258', 'Avg grade': 20.5}
# {'_id': '40365709', 'Avg grade': 20.5}
# {'_id': '41382650', 'Avg grade': 20.5}
# {'_id': '41702775', 'Avg grade': 20.5}
# {'_id': '41594622', 'Avg grade': 20.5}
# {'_id': '50006153', 'Avg grade': 20.5}
# {'_id': '41629759', 'Avg grade': 20.5}
# {'_id': '50003839', 'Avg grade': 20.5}
# {'_id': '41418376', 'Avg grade': 20.5}
# {'_id': '50000526', 'Avg grade': 20.5}
# {'_id': '40546727', 'Avg grade': 20.5}
# {'_id': '50005251', 'Avg grade': 20.5}
# {'_id': '40401217', 'Avg grade': 20.5}
# {'_id': '50008051', 'Avg grade': 20.5}
# {'_id': '50009235', 'Avg grade': 20.5}
# {'_id': '40996737', 'Avg grade': 20.5}
# {'_id': '41693949', 'Avg grade': 20.5}
# {'_id': '41670475', 'Avg grade': 20.5}
# {'_id': '41695960', 'Avg grade': 20.5}
# {'_id': '50000268', 'Avg grade': 20.5}
# {'_id': '41178943', 'Avg grade': 20.5}
# {'_id': '41681367', 'Avg grade': 20.5}
# {'_id': '50004873', 'Avg grade': 20.5}
# {'_id': '50008850', 'Avg grade': 20.5}
# ...
# {'_id': '50013672', 'Avg grade': 2.0}
# {'_id': '41396663', 'Avg grade': 2.0}
# {'_id': '50005495', 'Avg grade': 2.0}
# {'_id': '50016081', 'Avg grade': 2.0}
# {'_id': '50007739', 'Avg grade': 2.0}
# {'_id': '50006345', 'Avg grade': 2.0}
# {'_id': '50004275', 'Avg grade': 2.0}
# {'_id': '50009843', 'Avg grade': 2.0}
# {'_id': '50016746', 'Avg grade': 2.0}
# {'_id': '50005944', 'Avg grade': 2.0}
# {'_id': '50008135', 'Avg grade': 2.0}
# {'_id': '50003325', 'Avg grade': 2.0}
# {'_id': '50014277', 'Avg grade': 2.0}
# {'_id': '50005413', 'Avg grade': 2.0}
# {'_id': '50017080', 'Avg grade': 2.0}
# {'_id': '50017889', 'Avg grade': 2.0}
# {'_id': '50005196', 'Avg grade': 2.0}
# {'_id': '50013349', 'Avg grade': 2.0}
# {'_id': '50015032', 'Avg grade': 2.0}
# {'_id': '50015699', 'Avg grade': 2.0}
# {'_id': '50013202', 'Avg grade': 2.0}
# {'_id': '41531139', 'Avg grade': 2.0}
# {'_id': '50015922', 'Avg grade': 2.0}
# {'_id': '50004262', 'Avg grade': 2.0}
# {'_id': '50008354', 'Avg grade': 2.0}
# {'_id': '50009442', 'Avg grade': 2.0}
# {'_id': '50009394', 'Avg grade': 2.0}
# {'_id': '50016370', 'Avg grade': 2.0}
# {'_id': '50007589', 'Avg grade': 2.0}
# {'_id': '50009996', 'Avg grade': 2.0}
# {'_id': '50015790', 'Avg grade': 2.0}
# {'_id': '50002197', 'Avg grade': 2.0}
# {'_id': '50013421', 'Avg grade': 2.0}
# {'_id': '50016663', 'Avg grade': 2.0}
# {'_id': '41348028', 'Avg grade': 2.0}
# {'_id': '50017253', 'Avg grade': 2.0}
# {'_id': '50013436', 'Avg grade': 2.0}
# {'_id': '50016779', 'Avg grade': 2.0}
# {'_id': '50012509', 'Avg grade': 2.0}
# {'_id': '41643314', 'Avg grade': 2.0}
# {'_id': '50010908', 'Avg grade': 2.0}
# {'_id': '50012014', 'Avg grade': 2.0}
# {'_id': '50008841', 'Avg grade': 2.0}
# {'_id': '50002119', 'Avg grade': 2.0}
# {'_id': '41688265', 'Avg grade': 2.0}
# {'_id': '50017041', 'Avg grade': 2.0}
# {'_id': '40483729', 'Avg grade': 2.0}
# {'_id': '50014438', 'Avg grade': 2.0}
# {'_id': '50012234', 'Avg grade': 2.0}
# {'_id': '50018587', 'Avg grade': 2.0}
# {'_id': '50018291', 'Avg grade': 2.0}
# {'_id': '50007243', 'Avg grade': 2.0}
# {'_id': '50011590', 'Avg grade': 2.0}
# {'_id': '50015695', 'Avg grade': 2.0}
# {'_id': '41716834', 'Avg grade': 2.0}
# {'_id': '50005980', 'Avg grade': 2.0}
# {'_id': '50003360', 'Avg grade': 2.0}
# {'_id': '50006439', 'Avg grade': 2.0}
# {'_id': '50008624', 'Avg grade': 2.0}
# {'_id': '41694199', 'Avg grade': 2.0}
# {'_id': '50011620', 'Avg grade': 2.0}
# {'_id': '50016135', 'Avg grade': 2.0}
# {'_id': '50008853', 'Avg grade': 2.0}
# {'_id': '50005345', 'Avg grade': 2.0}
# {'_id': '50009346', 'Avg grade': 2.0}
# {'_id': '41696008', 'Avg grade': 2.0}
# {'_id': '50010296', 'Avg grade': 2.0}
# {'_id': '50006635', 'Avg grade': 2.0}
# {'_id': '50016802', 'Avg grade': 2.0}
# {'_id': '41684725', 'Avg grade': 2.0}
# {'_id': '50006240', 'Avg grade': 2.0}
# {'_id': '50017196', 'Avg grade': 2.0}
# {'_id': '50015698', 'Avg grade': 2.0}
# {'_id': '50016044', 'Avg grade': 2.0}
# {'_id': '50015881', 'Avg grade': 2.0}
# {'_id': '50003504', 'Avg grade': 2.0}
# {'_id': '50008206', 'Avg grade': 2.0}
# {'_id': '50018173', 'Avg grade': 2.0}
# {'_id': '50006055', 'Avg grade': 2.0}
# {'_id': '50011014', 'Avg grade': 2.0}
# {'_id': '50016109', 'Avg grade': 2.0}
# {'_id': '50011479', 'Avg grade': 2.0}
# {'_id': '50010673', 'Avg grade': 2.0}
# {'_id': '50001697', 'Avg grade': 2.0}
# {'_id': '50006399', 'Avg grade': 2.0}
# {'_id': '50007879', 'Avg grade': 2.0}
# {'_id': '50004570', 'Avg grade': 2.0}
# {'_id': '50016678', 'Avg grade': 2.0}
# {'_id': '50012641', 'Avg grade': 2.0}
# {'_id': '50016103', 'Avg grade': 2.0}
# {'_id': '50018344', 'Avg grade': 2.0}
# {'_id': '50011145', 'Avg grade': 2.0}
# {'_id': '50014168', 'Avg grade': 2.0}
# {'_id': '50016566', 'Avg grade': 2.0}
# {'_id': '50012880', 'Avg grade': 2.0}
# {'_id': '50004895', 'Avg grade': 2.0}
# {'_id': '50012053', 'Avg grade': 2.0}
# {'_id': '41666677', 'Avg grade': 2.0}
# {'_id': '50014086', 'Avg grade': 2.0}
# {'_id': '50013734', 'Avg grade': 2.0}
# {'_id': '50014316', 'Avg grade': 2.0}
# {'_id': '50017370', 'Avg grade': 2.0}
# {'_id': '50015984', 'Avg grade': 2.0}
# {'_id': '50004524', 'Avg grade': 2.0}
# {'_id': '50016473', 'Avg grade': 2.0}
# {'_id': '41702053', 'Avg grade': 2.0}
# {'_id': '50015857', 'Avg grade': 2.0}
# {'_id': '41395388', 'Avg grade': 2.0}
# {'_id': '50016600', 'Avg grade': 2.0}
# {'_id': '50009215', 'Avg grade': 2.0}
# {'_id': '50014901', 'Avg grade': 2.0}
# {'_id': '50017298', 'Avg grade': 2.0}
# {'_id': '50015333', 'Avg grade': 2.0}
# {'_id': '50012443', 'Avg grade': 2.0}
# {'_id': '50014588', 'Avg grade': 2.0}
# {'_id': '50011485', 'Avg grade': 2.0}
# {'_id': '50015567', 'Avg grade': 2.0}
# {'_id': '50006812', 'Avg grade': 2.0}
# {'_id': '50006129', 'Avg grade': 2.0}
# {'_id': '50012464', 'Avg grade': 2.0}
# {'_id': '50001503', 'Avg grade': 2.0}
# {'_id': '50013975', 'Avg grade': 2.0}
# {'_id': '50014973', 'Avg grade': 2.0}
# {'_id': '50013743', 'Avg grade': 2.0}
# {'_id': '50005900', 'Avg grade': 2.0}
# {'_id': '50010628', 'Avg grade': 2.0}
# {'_id': '50001937', 'Avg grade': 2.0}
# {'_id': '50018705', 'Avg grade': 2.0}
# {'_id': '41396859', 'Avg grade': 2.0}
# {'_id': '50008032', 'Avg grade': 2.0}
# {'_id': '50014394', 'Avg grade': 2.0}
# {'_id': '50002435', 'Avg grade': 2.0}
# {'_id': '50010472', 'Avg grade': 2.0}
# {'_id': '50013014', 'Avg grade': 2.0}
# {'_id': '50017681', 'Avg grade': 2.0}
# {'_id': '50016892', 'Avg grade': 2.0}
# {'_id': '41448070', 'Avg grade': 2.0}
# {'_id': '50017471', 'Avg grade': 2.0}
# {'_id': '50006147', 'Avg grade': 2.0}
# {'_id': '50016209', 'Avg grade': 2.0}
# {'_id': '50017156', 'Avg grade': 2.0}
# {'_id': '50018059', 'Avg grade': 2.0}
# {'_id': '50018283', 'Avg grade': 2.0}
# {'_id': '50015975', 'Avg grade': 2.0}
# {'_id': '50009058', 'Avg grade': 2.0}
# {'_id': '50013849', 'Avg grade': 2.0}
# {'_id': '50006703', 'Avg grade': 2.0}
# {'_id': '41490486', 'Avg grade': 2.0}
# {'_id': '50010930', 'Avg grade': 2.0}
# {'_id': '41153089', 'Avg grade': 2.0}
# {'_id': '50008162', 'Avg grade': 2.0}
# {'_id': '50018732', 'Avg grade': 2.0}
# {'_id': '41711610', 'Avg grade': 2.0}
# {'_id': '50004111', 'Avg grade': 2.0}
# {'_id': '50014624', 'Avg grade': 2.0}
# {'_id': '50018433', 'Avg grade': 2.0}
# {'_id': '50017311', 'Avg grade': 2.0}
# {'_id': '50011489', 'Avg grade': 2.0}
# {'_id': '50015317', 'Avg grade': 2.0}
# {'_id': '40592920', 'Avg grade': 1.75}
# {'_id': '41549226', 'Avg grade': 1.75}
# {'_id': '40938945', 'Avg grade': 1.75}
# {'_id': '40673275', 'Avg grade': 1.75}
# {'_id': '41395428', 'Avg grade': 1.75}
# {'_id': '41552363', 'Avg grade': 1.75}
# {'_id': '41376075', 'Avg grade': 1.75}
# {'_id': '41494671', 'Avg grade': 1.6666666666666667}
# {'_id': '41395509', 'Avg grade': 1.6666666666666667}
# {'_id': '41618364', 'Avg grade': 1.6666666666666667}
# {'_id': '40610155', 'Avg grade': 1.6666666666666667}
# {'_id': '41618395', 'Avg grade': 1.6666666666666667}
# {'_id': '41564945', 'Avg grade': 1.6666666666666667}
# {'_id': '41618372', 'Avg grade': 1.6666666666666667}
# {'_id': '40386837', 'Avg grade': 1.6666666666666667}
# {'_id': '50001057', 'Avg grade': 1.6}
# {'_id': '41611658', 'Avg grade': 1.5}
# {'_id': '41396647', 'Avg grade': 1.5}
# {'_id': '50000992', 'Avg grade': 1.5}
# {'_id': '41712818', 'Avg grade': 1.5}
# {'_id': '50002397', 'Avg grade': 1.5}
# {'_id': '50002107', 'Avg grade': 1.5}
# {'_id': '41395424', 'Avg grade': 1.3333333333333333}
# {'_id': '41620012', 'Avg grade': 1.3333333333333333}
# {'_id': '41719425', 'Avg grade': 1.3333333333333333}
# {'_id': '41395432', 'Avg grade': 1.3333333333333333}
# {'_id': '41618435', 'Avg grade': 1.3333333333333333}
# {'_id': '41687898', 'Avg grade': 1.3333333333333333}
# {'_id': '41618377', 'Avg grade': 1.3333333333333333}
# {'_id': '41618437', 'Avg grade': 1.3333333333333333}
# {'_id': '41459709', 'Avg grade': 1.3333333333333333}
# {'_id': '41362524', 'Avg grade': 1.3333333333333333}
# {'_id': '41642422', 'Avg grade': 1.3333333333333333}
# {'_id': '41618397', 'Avg grade': 1.3333333333333333}
# {'_id': '41618374', 'Avg grade': 1.3333333333333333}
# {'_id': '50000499', 'Avg grade': 1.3333333333333333}
# {'_id': '41395502', 'Avg grade': 1.3333333333333333}
# {'_id': '41611667', 'Avg grade': 1.3333333333333333}
# {'_id': '50002725', 'Avg grade': 1.0}
# {'_id': '41688157', 'Avg grade': 1.0}
# {'_id': '41696848', 'Avg grade': 1.0}
# {'_id': '41393345', 'Avg grade': 1.0}
# {'_id': '50000697', 'Avg grade': 1.0}
# {'_id': '40928096', 'Avg grade': 1.0}
# {'_id': '40716961', 'Avg grade': 1.0}
# {'_id': '41701450', 'Avg grade': 1.0}
# {'_id': '41611718', 'Avg grade': 1.0}
# {'_id': '50004569', 'Avg grade': 1.0}
# {'_id': '50011554', 'Avg grade': 1.0}
# {'_id': '41720441', 'Avg grade': 1.0}
# {'_id': '50004211', 'Avg grade': 1.0}
# {'_id': '41704965', 'Avg grade': 1.0}
# {'_id': '41688116', 'Avg grade': 1.0}
# {'_id': '41694614', 'Avg grade': 1.0}
# {'_id': '50001347', 'Avg grade': 1.0}
# {'_id': '41688137', 'Avg grade': 1.0}
# {'_id': '50001830', 'Avg grade': 1.0}
# {'_id': '41618410', 'Avg grade': 1.0}
# {'_id': '41490374', 'Avg grade': 1.0}
# {'_id': '41667870', 'Avg grade': 0.8}
# {'_id': '41618402', 'Avg grade': 0.6666666666666666}
# {'_id': '41620014', 'Avg grade': 0.6666666666666666}
# {'_id': '41564963', 'Avg grade': 0.6666666666666666}
# {'_id': '41618427', 'Avg grade': 0.6666666666666666}
# {'_id': '41618392', 'Avg grade': 0.6666666666666666}
# {'_id': '41395535', 'Avg grade': 0.6666666666666666}
# {'_id': '40761262', 'Avg grade': 0.6666666666666666}
# {'_id': '41620013', 'Avg grade': 0.6666666666666666}
# {'_id': '41618384', 'Avg grade': 0.6666666666666666}
# {'_id': '41656214', 'Avg grade': 0.6666666666666666}
# {'_id': '41618421', 'Avg grade': 0.6666666666666666}
# {'_id': '41618440', 'Avg grade': 0.6666666666666666}
# {'_id': '41618407', 'Avg grade': 0.6666666666666666}
# {'_id': '41618389', 'Avg grade': 0.6666666666666666}
# {'_id': '41618385', 'Avg grade': 0.6666666666666666}
# {'_id': '41618408', 'Avg grade': 0.6666666666666666}
# {'_id': '41611720', 'Avg grade': 0.5}
# {'_id': '41611748', 'Avg grade': 0.5}
# {'_id': '50017438', 'Avg grade': 0.0}
# {'_id': '50017003', 'Avg grade': 0.0}
# {'_id': '50006343', 'Avg grade': 0.0}
# {'_id': '50005742', 'Avg grade': 0.0}
# {'_id': '50018355', 'Avg grade': 0.0}
# {'_id': '50016741', 'Avg grade': 0.0}
# {'_id': '50013111', 'Avg grade': 0.0}
# {'_id': '50011704', 'Avg grade': 0.0}
# {'_id': '50005547', 'Avg grade': 0.0}
# {'_id': '50014402', 'Avg grade': 0.0}
# {'_id': '50003469', 'Avg grade': 0.0}
# {'_id': '50016616', 'Avg grade': 0.0}
# {'_id': '41620017', 'Avg grade': 0.0}
# {'_id': '50012467', 'Avg grade': 0.0}
# {'_id': '50002468', 'Avg grade': 0.0}
# {'_id': '50018399', 'Avg grade': 0.0}
# {'_id': '50003927', 'Avg grade': 0.0}
# {'_id': '50012001', 'Avg grade': 0.0}
# {'_id': '50001438', 'Avg grade': 0.0}
# {'_id': '41395419', 'Avg grade': 0.0}
# {'_id': '50016720', 'Avg grade': 0.0}
# {'_id': '50017418', 'Avg grade': 0.0}
# {'_id': '50017792', 'Avg grade': 0.0}
# {'_id': '50008083', 'Avg grade': 0.0}
# {'_id': '50009344', 'Avg grade': 0.0}
# {'_id': '41694762', 'Avg grade': 0.0}
# {'_id': '50014090', 'Avg grade': 0.0}
# {'_id': '41618358', 'Avg grade': 0.0}
# {'_id': '50014655', 'Avg grade': 0.0}
# {'_id': '50008187', 'Avg grade': 0.0}
# {'_id': '41611726', 'Avg grade': 0.0}
# {'_id': '50007471', 'Avg grade': 0.0}
# {'_id': '41618387', 'Avg grade': 0.0}
# {'_id': '50015221', 'Avg grade': 0.0}
# {'_id': '50016951', 'Avg grade': 0.0}
# {'_id': '50011616', 'Avg grade': 0.0}
# {'_id': '50013890', 'Avg grade': 0.0}
# {'_id': '50013960', 'Avg grade': 0.0}
# {'_id': '50002969', 'Avg grade': 0.0}
# {'_id': '50002117', 'Avg grade': 0.0}
# {'_id': '41611725', 'Avg grade': 0.0}
# {'_id': '41688112', 'Avg grade': 0.0}
# {'_id': '41694617', 'Avg grade': 0.0}
# {'_id': '41564948', 'Avg grade': 0.0}
# {'_id': '50009700', 'Avg grade': 0.0}
# {'_id': '50012132', 'Avg grade': 0.0}
# {'_id': '50016642', 'Avg grade': 0.0}
# {'_id': '50013738', 'Avg grade': 0.0}
# {'_id': '41618411', 'Avg grade': 0.0}
# {'_id': '50008235', 'Avg grade': 0.0}
# {'_id': '41401790', 'Avg grade': 0.0}
# {'_id': '50017920', 'Avg grade': 0.0}
# {'_id': '41694730', 'Avg grade': 0.0}
# {'_id': '50001548', 'Avg grade': 0.0}
# {'_id': '50004721', 'Avg grade': 0.0}
# {'_id': '50017756', 'Avg grade': 0.0}
# {'_id': '50017286', 'Avg grade': 0.0}
# {'_id': '50015327', 'Avg grade': 0.0}
# {'_id': '41618400', 'Avg grade': 0.0}
# {'_id': '50014467', 'Avg grade': 0.0}
# {'_id': '50017295', 'Avg grade': 0.0}
# {'_id': '50017146', 'Avg grade': 0.0}
# {'_id': '41603665', 'Avg grade': 0.0}
# {'_id': '50009755', 'Avg grade': 0.0}
# {'_id': '41702471', 'Avg grade': 0.0}
# {'_id': '50017209', 'Avg grade': 0.0}
# {'_id': '50002974', 'Avg grade': 0.0}
# {'_id': '50013607', 'Avg grade': 0.0}
# {'_id': '50018049', 'Avg grade': 0.0}
# {'_id': '41564934', 'Avg grade': 0.0}
# {'_id': '50008061', 'Avg grade': 0.0}
# {'_id': '50015814', 'Avg grade': 0.0}
# {'_id': '50009342', 'Avg grade': 0.0}
# {'_id': '50005387', 'Avg grade': 0.0}
# {'_id': '50007736', 'Avg grade': 0.0}
# {'_id': '50006271', 'Avg grade': 0.0}
# {'_id': '50014836', 'Avg grade': 0.0}
# {'_id': '50000360', 'Avg grade': 0.0}
# {'_id': '50017242', 'Avg grade': 0.0}
# {'_id': '50017599', 'Avg grade': 0.0}
# {'_id': '41564928', 'Avg grade': 0.0}
# {'_id': '50007375', 'Avg grade': 0.0}
# {'_id': '50008239', 'Avg grade': 0.0}
# {'_id': '50016699', 'Avg grade': 0.0}
# {'_id': '50000576', 'Avg grade': 0.0}
# {'_id': '50008364', 'Avg grade': 0.0}
# {'_id': '50017177', 'Avg grade': 0.0}
# {'_id': '41694754', 'Avg grade': 0.0}
# {'_id': '50007910', 'Avg grade': 0.0}
# {'_id': '50006244', 'Avg grade': 0.0}
# {'_id': '41694756', 'Avg grade': 0.0}
# {'_id': '50002425', 'Avg grade': 0.0}
# {'_id': '41618368', 'Avg grade': 0.0}
# {'_id': '50005823', 'Avg grade': 0.0}
# {'_id': '41618345', 'Avg grade': 0.0}
# {'_id': '50015801', 'Avg grade': 0.0}
# {'_id': '50016675', 'Avg grade': 0.0}
# {'_id': '50014737', 'Avg grade': 0.0}
# {'_id': '50018565', 'Avg grade': 0.0}
# {'_id': '50016224', 'Avg grade': 0.0}
# {'_id': '50005218', 'Avg grade': 0.0}
# {'_id': '50006349', 'Avg grade': 0.0}
# {'_id': '50014541', 'Avg grade': 0.0}
# {'_id': '50015809', 'Avg grade': 0.0}
# {'_id': '50008540', 'Avg grade': 0.0}
# {'_id': '50016882', 'Avg grade': 0.0}
# {'_id': '50015724', 'Avg grade': 0.0}
# {'_id': '50013145', 'Avg grade': 0.0}
# {'_id': '41712685', 'Avg grade': 0.0}
# {'_id': '50007672', 'Avg grade': 0.0}
# {'_id': '50013649', 'Avg grade': 0.0}
# {'_id': '41694620', 'Avg grade': 0.0}
# {'_id': '41694763', 'Avg grade': 0.0}
# {'_id': '50006347', 'Avg grade': 0.0}
# {'_id': '50008750', 'Avg grade': 0.0}
# {'_id': '50018387', 'Avg grade': 0.0}
# {'_id': '41694760', 'Avg grade': 0.0}
# {'_id': '50016358', 'Avg grade': 0.0}
# {'_id': '50016604', 'Avg grade': 0.0}
# {'_id': '50015537', 'Avg grade': 0.0}
# {'_id': '50007319', 'Avg grade': 0.0}
# {'_id': '50012654', 'Avg grade': 0.0}
# {'_id': '50014677', 'Avg grade': 0.0}
# {'_id': '50016528', 'Avg grade': 0.0}
# {'_id': '50016459', 'Avg grade': 0.0}
# {'_id': '50003180', 'Avg grade': 0.0}
# {'_id': '50017983', 'Avg grade': 0.0}
# {'_id': '41618405', 'Avg grade': 0.0}
# {'_id': '50015980', 'Avg grade': 0.0}
# {'_id': '41694727', 'Avg grade': 0.0}
# {'_id': '41694764', 'Avg grade': 0.0}
# {'_id': '50007853', 'Avg grade': 0.0}
# {'_id': '41694753', 'Avg grade': 0.0}
# {'_id': '50015526', 'Avg grade': 0.0}
# {'_id': '50018450', 'Avg grade': 0.0}
# {'_id': '50010945', 'Avg grade': 0.0}
# {'_id': '50014997', 'Avg grade': 0.0}
# {'_id': '50010165', 'Avg grade': 0.0}
# {'_id': '41694724', 'Avg grade': 0.0}
# {'_id': '50013755', 'Avg grade': 0.0}
# {'_id': '50016826', 'Avg grade': 0.0}
# {'_id': '50002674', 'Avg grade': 0.0}
# {'_id': '50016987', 'Avg grade': 0.0}
# {'_id': '41694749', 'Avg grade': 0.0}
# {'_id': '50003209', 'Avg grade': 0.0}
# {'_id': '50016958', 'Avg grade': 0.0}
# {'_id': '41713865', 'Avg grade': 0.0}
# {'_id': '50016154', 'Avg grade': 0.0}
# {'_id': '41564956', 'Avg grade': 0.0}
# {'_id': '50013144', 'Avg grade': 0.0}
# {'_id': '50015679', 'Avg grade': 0.0}
# {'_id': '50009217', 'Avg grade': 0.0}
# {'_id': '41694611', 'Avg grade': 0.0}
# {'_id': '50012634', 'Avg grade': -1.0}
# {'_id': '50013675', 'Avg grade': None}
# {'_id': '50011122', 'Avg grade': None}
# {'_id': '50015485', 'Avg grade': None}
# {'_id': '41278206', 'Avg grade': None}
# {'_id': '50013829', 'Avg grade': None}
# {'_id': '50016474', 'Avg grade': None}
# {'_id': '50016458', 'Avg grade': None}
# {'_id': '50013184', 'Avg grade': None}
# {'_id': '50015236', 'Avg grade': None}
# {'_id': '50016322', 'Avg grade': None}
# {'_id': '50015977', 'Avg grade': None}
# {'_id': '50016957', 'Avg grade': None}
# {'_id': '50018084', 'Avg grade': None}

# %% [markdown]
# # Convert data from a Mongo database into tabular form as a Panda’s dataframe object

# %%
import pandas as pd

extracted_data = restaurants.find({},{"borough": "Bronx", "cuisine": "Bakery", "name": 1})
bronx_bakeries = list(extracted_data)

bakeries=pd.DataFrame.from_dict(bronx_bakeries)
bakeries = bakeries.set_index("_id")

# %%
bakeries
# Out:
#                                                        name borough cuisine
# _id
# 641a0e7d5e7639d44270ac41              Morris Park Bake Shop   Bronx  Bakery
# 641a0e7d5e7639d44270ac42                            Wendy'S   Bronx  Bakery
# 641a0e7d5e7639d44270ac43     Dj Reynolds Pub And Restaurant   Bronx  Bakery
# 641a0e7d5e7639d44270ac44                    Riviera Caterer   Bronx  Bakery
# 641a0e7d5e7639d44270ac45                 Tov Kosher Kitchen   Bronx  Bakery
# ...                                                     ...     ...     ...
# 641a0e7d5e7639d442710f4b                             Subway   Bronx  Bakery
# 641a0e7d5e7639d442710f4c  Fairfield Inn Suites Penn Station   Bronx  Bakery
# 641a0e7d5e7639d442710f4d                                      Bronx  Bakery
# 641a0e7d5e7639d442710f4e                        Indian Oven   Bronx  Bakery
# 641a0e7d5e7639d442710f4f                       Cold Press'D   Bronx  Bakery
#
# [25359 rows x 3 columns]

# %% [markdown]
# # Using the mongodb query and a python dataframe:
#
# Show a table and a chart with the average ratings per restarurant, the top 5 and the tail 5.
#
# Since the tail 5 will show no valid info, remove nulls and also remove those with avg rating 0,
# show the remianing ones

# %%
#complete the code:

result = restaurants.aggregate( 
  [
     {"$match": {}}, 
     {"$unwind": "$grades"},
     {"$group": {"_id": "$restaurant_id", "Avg grade": {"$avg": "$grades.score" }}},
  ]
)
bakeriesAVGPD=pd.DataFrame(list(result))
bakeriesAVGPD=bakeriesAVGPD.dropna().sort_values("Avg grade",ascending=False)

# %%
pd.concat([bakeriesAVGPD.head(5),bakeriesAVGPD.tail(5)])
# Out:
#             _id  Avg grade
# 19669  50015959       75.0
# 17078  50017374       73.0
# 2141   50015245       69.0
# 13859  50018457       69.0
# 12270  41703965       65.0
# 19573  50012467        0.0
# 5010   41694724        0.0
# 9653   50015809        0.0
# 6559   50000576        0.0
# 13451  50012634       -1.0

# %%
#complete to plot the top 5 chart:

import matplotlib.pyplot as plt

plt.bar(bakeriesAVGPD.head(5)['_id'],bakeriesAVGPD.head(5)["Avg grade"])
plt.xticks(rotation=90)
plt.show()

# %%
#complete to plot the top 5 chart:

import matplotlib.pyplot as plt

plt.bar(bakeriesAVGPD.tail(5)['_id'],bakeriesAVGPD.tail(5)["Avg grade"])
plt.xticks(rotation=90)
plt.show()

# %%
#drop rows with null values and complete the following code to work well

filter = bakeriesAVGPD["Avg grade"]>0
  
# filtering data
bakeriesAVGPD1=bakeriesAVGPD.where(filter, inplace = False)
  
# display
bakeriesAVGPD1.dropna()
# Out:
#             _id  Avg grade
# 19669  50015959  75.000000
# 17078  50017374  73.000000
# 2141   50015245  69.000000
# 13859  50018457  69.000000
# 12270  41703965  65.000000
# ...         ...        ...
# 23399  41618402   0.666667
# 1974   41618440   0.666667
# 3577   41618385   0.666667
# 5296   41611748   0.500000
# 12711  41611720   0.500000
#
# [24454 rows x 2 columns]

# %% [markdown]
# # Next we want to see avergae grades per LOCATION (borough=neighborhood) instead of per restaurant

# %% [markdown]
# 'address': {'building': '1007',
#              'coord': [-73.856077, 40.848447],
#              'street': 'Morris Park Ave',
#              'zipcode': '10462'},

# %%
# Show tables with the average, max and stdev ratings per location, charts with top 5, tail 5 and all of average 
# rating

result = restaurants.aggregate(
  [
     {"$unwind": "$grades"},
     {"$match": {}},
     {"$facet" : [
        {"$group": {"_id": "$borough", "Avg grade": {"$avg": "$grades.score" }}},
        {"$group": {"_id": "$borough", "Max grade": {"$max": "$grades.score" }}},
      ],
     },
  ]
)

bakeriesAVG = list(result)

bakeriesAVGPD=pd.DataFrame(bakeriesAVG)
bakeriesAVGPD
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[102], line 4
#       1 # Show tables with the average, max and stdev ratings per location, charts with top 5, tail 5 and all of average
#       2 # rating
# ----> 4 result = restaurants.aggregate(
#       5   [
#       6      {"$unwind": "$grades"},
#       7      {"$facet" : [
#       8         {"$group": {"_id": "$borough", "Avg grade": {"$avg": "$grades.score" }}},
#       9         {"$group": {"_id": "$borough", "Max grade": {"$max": "$grades.score" }}},
#      10       ],
#      11      },
#      12   ]
#      13 )
#      15 bakeriesAVG = list(result)
#      17 bakeriesAVGPD=pd.DataFrame(bakeriesAVG)
#
# File /opt/conda/lib/python3.10/site-packages/pymongo/collection.py:2436, in Collection.aggregate(self, pipeline, session, let, comment, **kwargs)
#    2358 """Perform an aggregation using the aggregation framework on this
#    2359 collection.
#    2360
#    (...)
#    2432     https://mongodb.com/docs/manual/reference/command/aggregate
#    2433 """
#    2435 with self.__database.client._tmp_session(session, close=False) as s:
# -> 2436     return self._aggregate(
#    2437         _CollectionAggregationCommand,
#    2438         pipeline,
#    2439         CommandCursor,
#    2440         session=s,
#    2441         explicit_session=session is not None,
#    2442         let=let,
#    2443         comment=comment,
#    2444         **kwargs,
#    2445     )
#
# File /opt/conda/lib/python3.10/site-packages/pymongo/_csot.py:105, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     103         with _TimeoutContext(timeout):
#     104             return func(self, *args, **kwargs)
# --> 105 return func(self, *args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/pymongo/collection.py:2343, in Collection._aggregate(self, aggregation_command, pipeline, cursor_class, session, explicit_session, let, comment, **kwargs)
#    2332     kwargs["comment"] = comment
#    2333 cmd = aggregation_command(
#    2334     self,
#    2335     cursor_class,
#    (...)
#    2340     user_fields={"cursor": {"firstBatch": 1}},
#    2341 )
# -> 2343 return self.__database.client._retryable_read(
#    2344     cmd.get_cursor,
#    2345     cmd.get_read_preference(session),
#    2346     session,
#    2347     retryable=not cmd._performs_write,
#    2348 )
#
# File /opt/conda/lib/python3.10/site-packages/pymongo/_csot.py:105, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     103         with _TimeoutContext(timeout):
#     104             return func(self, *args, **kwargs)
# --> 105 return func(self, *args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/pymongo/mongo_client.py:1448, in MongoClient._retryable_read(self, func, read_pref, session, address, retryable)
#    1446             assert last_error is not None
#    1447             raise last_error
# -> 1448         return func(session, server, sock_info, read_pref)
#    1449 except ServerSelectionTimeoutError:
#    1450     if retrying:
#    1451         # The application may think the write was never attempted
#    1452         # if we raise ServerSelectionTimeoutError on the retry
#    1453         # attempt. Raise the original exception instead.
#
# File /opt/conda/lib/python3.10/site-packages/pymongo/aggregation.py:142, in _AggregationCommand.get_cursor(self, session, server, sock_info, read_preference)
#     139     write_concern = None
#     141 # Run command.
# --> 142 result = sock_info.command(
#     143     self._database.name,
#     144     cmd,
#     145     read_preference,
#     146     self._target.codec_options,
#     147     parse_write_concern_error=True,
#     148     read_concern=read_concern,
#     149     write_concern=write_concern,
#     150     collation=self._collation,
#     151     session=session,
#     152     client=self._database.client,
#     153     user_fields=self._user_fields,
#     154 )
#     156 if self._result_processor:
#     157     self._result_processor(result, sock_info)
#
# File /opt/conda/lib/python3.10/site-packages/pymongo/pool.py:767, in SocketInfo.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     765     self._raise_if_not_writable(unacknowledged)
#     766 try:
# --> 767     return command(
#     768         self,
#     769         dbname,
#     770         spec,
#     771         self.is_mongos,
#     772         read_preference,
#     773         codec_options,
#     774         session,
#     775         client,
#     776         check,
#     777         allowable_errors,
#     778         self.address,
#     779         listeners,
#     780         self.max_bson_size,
#     781         read_concern,
#     782         parse_write_concern_error=parse_write_concern_error,
#     783         collation=collation,
#     784         compression_ctx=self.compression_context,
#     785         use_op_msg=self.op_msg_enabled,
#     786         unacknowledged=unacknowledged,
#     787         user_fields=user_fields,
#     788         exhaust_allowed=exhaust_allowed,
#     789         write_concern=write_concern,
#     790     )
#     791 except (OperationFailure, NotPrimaryError):
#     792     raise
#
# File /opt/conda/lib/python3.10/site-packages/pymongo/network.py:166, in command(sock_info, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     164             client._process_response(response_doc, session)
#     165         if check:
# --> 166             helpers._check_command_response(
#     167                 response_doc,
#     168                 sock_info.max_wire_version,
#     169                 allowable_errors,
#     170                 parse_write_concern_error=parse_write_concern_error,
#     171             )
#     172 except Exception as exc:
#     173     if publish:
#
# File /opt/conda/lib/python3.10/site-packages/pymongo/helpers.py:181, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     178 elif code == 43:
#     179     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 181 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: the $facet specification must be a non-empty object, but found: $facet: [ { $group: { _id: "$borough", Avg grade: { $avg: "$grades.score" } } }, { $group: { _id: "$borough", Max grade: { $max: "$grades.score" } } } ], full error: {'ok': 0.0, 'errmsg': 'the $facet specification must be a non-empty object, but found: $facet: [ { $group: { _id: "$borough", Avg grade: { $avg: "$grades.score" } } }, { $group: { _id: "$borough", Max grade: { $max: "$grades.score" } } } ]', 'code': 40169, 'codeName': 'Location40169'}

# %%
#complete to show the head and tail 5

import matplotlib.pyplot as plt

plt.bar(bakeriesAVGPD.head(5)['?'],bakeriesAVGPD.head(5)["?"])
plt.xticks(rotation=90)
plt.show()

?

# %%
#complete to show all values

plt.bar(bakeriesAVGPD['?'],bakeriesAVGPD["?"])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # The end !!!!
